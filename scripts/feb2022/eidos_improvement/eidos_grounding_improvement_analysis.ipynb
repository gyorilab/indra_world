# %%
import os
import csv
import glob
from indra_world.sources import eidos
from indra.statements import Event

# %%
parts = ['amyoutput', 'winoutput1', 'winoutput2']
stmts = {}
for part in parts:
    fnames = glob.glob(part + '/*.jsonld')
    stmts[part] = []
    for fname in fnames:
        doc = os.path.basename(fname)[:-7]
        ep = eidos.process_json_file(fname, extract_filter=['influence'])
        ep.extract_all_events()
        fix_provenance(doc, ep.statements)
        stmts[part] += ep.statements

# %%
def fix_provenance(fname, stmts):
    doc_id = os.path.basename(fname).split('.')[0]
    for stmt in stmts:
        for ev in stmt.evidence:
            ev.text_refs['DART'] = doc_id


def get_indexed_event(event):
    wmgr = event.concept.db_refs.get('WM')
    gr = None if not wmgr else wmgr[0]
    doc_char_pos = event.evidence[0].annotations['provenance'][0]['documentCharPositions']
    if isinstance(doc_char_pos, list):
        pos = doc_char_pos[0]
    else:
        pos = doc_char_pos
    doc_id = event.evidence[0].text_refs['DART']
    key = (doc_id, pos['start'], pos['end'])
    return key, gr, event.concept.db_refs['TEXT']


def get_indexed_events(stmts):
    indexed_events = {}
    for stmt in stmts:
        if isinstance(stmt, Event):
            key, gr, text = get_indexed_event(stmt)
            if not key:
                continue
            indexed_events[key] = (gr, text)
    return indexed_events

# %%
indexed_events = {}
for part in parts:
    indexed_events[part] = get_indexed_events(stmts[part])

# %%
indexed_events
# Out:
# {'amyoutput': {('0a6200447248b0bfb4a67d0fb5e84cbd',
#    344,
#    355): ([('wm/concept/environment/climate', 1.0),
#     None,
#     ('wm/process/communication/informing', 0.876518726348877),
#     None], 'climate news'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    433,
#    459): ([('wm/process/communication/informing', 0.8533480167388916),
#     ('wm/property/stability', 1.0509308576583862),
#     None,
#     None], 'You may not have noticed it'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    522,
#    571): ([('wm/concept/environment/climate', 1.0),
#     None,
#     ('wm/process/communication/meeting', 1.7538217306137085),
#     None], 'collapse of the COP25 climate conference in Madrid'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    566,
#    571): ([('wm/concept/economy/tourism', 0.63947594165802),
#     None,
#     None,
#     None], 'Madrid'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    901,
#    934): ([('wm/property/preparedness', 0.8710763454437256),
#     None,
#     None,
#     None], 'both the most optimistic scenarios'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    944,
#    964): ([('wm/concept/perception', 0.884898841381073),
#     None,
#     None,
#     None], 'most pessimistic ones'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    1212,
#    1233): ([('wm/property/stability', 0.8919515013694763),
#     None,
#     None,
#     None], 'both good and bad news'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    1387,
#    1395): ([('wm/property/quality', 0.9921055436134338),
#     None,
#     None,
#     None], 'good news'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    1541,
#    1604): ([('wm/concept/environment/climate', 1.0),
#     None,
#     ('wm/process/communication/campaign', 1.2903261184692383),
#     None], 'IEA is not known to be optimistic, at least to climate advocates'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    1818,
#    1843): ([('wm/process/prediction', 1.0),
#     ('wm/property/widespread', 1.0096060037612915),
#     None,
#     None], 'most noteworthy prediction'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    1898,
#    1907): ([('wm/concept/entity/hamas', 0.622750997543335),
#     ('wm/property/aftermath', 0.876968264579773),
#     None,
#     None], 'IEA report'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    1916,
#    1943): ([('wm/concept/environment/natural_resources/fossil_fuels',
#      1.6655217409133911),
#     ('wm/property/stability', 0.9848251938819885),
#     None,
#     None], 'only current carbon policies'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    1952,
#    1983): ([('wm/concept/environment/climate', 1.0),
#     None,
#     ('wm/process/research', 0.9967037439346313),
#     None], 'nearly everyone studying climate'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    2173,
#    2202): ([('wm/property/price_or_cost', 1.0446996688842773),
#     None,
#     None,
#     None], 'less warming than is suggested'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    2285,
#    2303): ([('wm/concept/entity/hamas', 0.5023889541625977),
#     None,
#     None,
#     None], '" "RCP8.5" scenario'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    2471,
#    2504): ([('wm/property/preparedness', 0.9909564852714539),
#     None,
#     None,
#     None], 'their last major assessment report'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    2577,
#    2600): ([('wm/process/start', 0.7087772488594055),
#     ('wm/property/quality', 0.9116207361221313),
#     None,
#     None], 'highest arc of emissions'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    3081,
#    3103): ([('wm/process/farming/planting', 0.9372536540031433),
#     None,
#     None,
#     None], 'Those deep in the weeds'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    3310,
#    3344): ([('wm/property/aftermath', 0.9644799828529358),
#     None,
#     None,
#     None], 'deep - and perhaps fatal - problems'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd', 3315, 3315): (None, '-'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    3487,
#    3502): ([('wm/property/volatility', 0.9331188201904297),
#     None,
#     None,
#     None], 'usual" scenarios'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    3908,
#    3927): ([('wm/property/stability', 1.0292072296142578),
#     None,
#     None,
#     None], 'that global coal use'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    4206,
#    4233): ([('wm/property/stability', 1.0663681030273438),
#     None,
#     None,
#     None], 'perhaps even dramatic growth'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    4344,
#    4386): ([('wm/concept/plan', 1.5115242004394531),
#     ('wm/property/stability', 1.0509308576583862),
#     None,
#     None], "given how much we don't know about the path"),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    4479,
#    4511): ([('wm/process/flow', 0.7172248959541321),
#     ('wm/property/aftermath', 1.0198456048965454),
#     None,
#     None], 'recent drops in renewable pricing'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    4495,
#    4511): ([('wm/property/price_or_cost', 1.008305311203003),
#     None,
#     None,
#     None], 'renewable pricing'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    4522,
#    4575): ([('wm/process/detection', 1.659497618675232),
#     ('wm/property/geographic_resolution/global', 1.9016761779785156),
#     None,
#     None], 'positive signs for coal decline in the developed world'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    4541,
#    4575): ([('wm/property/geographic_resolution/global', 1.9016761779785156),
#     None,
#     None,
#     None], 'coal decline in the developed world'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    4561,
#    4575): ([('wm/property/geographic_resolution/global', 1.0854711532592773),
#     None,
#     None,
#     None], 'developed world'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    4791,
#    4866): ([('wm/concept/energy', 1.0),
#     None,
#     ('wm/process/communication/description', 0.7926035523414612),
#     None], 'energy use, which is not at all the whole picture when it comes to emissions'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    5044,
#    5087): ([('wm/process/prediction', 1.2336145639419556),
#     ('wm/property/price_or_cost', 1.031987190246582),
#     None,
#     None], 'coal use fails to grow at the predicted rate'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    5124,
#    5138): ([('wm/concept/environment/climate', 1.0),
#     ('wm/property/preparedness', 0.8960893154144287),
#     None,
#     None], 'climate impacts'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    5390,
#    5408): ([('wm/property/diversity', 0.9957168698310852),
#     None,
#     None,
#     None], 'large uncertainties'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    5476,
#    5502): ([('wm/process/communication/highlighting', 0.7707635760307312),
#     None,
#     None,
#     None], 'remarkably insightful paper'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    5476,
#    5670): ([('wm/concept/environment/climate', 1.0),
#     None,
#     ('wm/process/publication', 1.1587711572647095),
#     None], 'remarkably insightful paper published by the Breakthrough Institute on Wednesday - "in a right and just world, this would be the most high-impact piece of climate writing of the month of December'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    5814,
#    5842): ([('wm/concept/cultural_norms', 0.8997845649719238),
#     None,
#     None,
#     None], 'very conservative assumptions'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    6149,
#    6208): ([('wm/concept/energy', 1.0),
#     None,
#     ('wm/process/modification', 0.73780357837677),
#     None], 'transitions in the global energy system over the past decade'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    6222,
#    6312): ([('wm/concept/trend', 1.0),
#     None,
#     ('wm/process/prediction', 1.5695524215698242),
#     None], 'conservative business-as-usual projection of current trends in the energy system continuing'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    6339,
#    6366): ([('wm/concept/time', 0.7698357701301575),
#     ('wm/property/geographic_resolution/global', 0.8593756556510925),
#     None,
#     None], 'warming of around 3C by 2100'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd', 6404, 6459): (None,
#    'higher-emissions world than the IEA projects is possible'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    6665,
#    6681): ([('wm/property/preparedness', 1.0092500448226929),
#     None,
#     None,
#     None], 'absence of policy'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    6693,
#    6729): ([('wm/property/price_or_cost', 1.031987190246582),
#     None,
#     None,
#     None], 'rate of emissions reductions required'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    7186,
#    7287): ([('wm/concept/environment/climate', 1.0),
#     ('wm/property/stability', 1.0663681030273438),
#     None,
#     None], 'that they did not see RCP8.5 as a plausible scenario, even in the absence of meaningful climate policy'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    7240,
#    7287): ([('wm/concept/environment/climate', 1.0),
#     ('wm/property/stability', 1.0663681030273438),
#     None,
#     None], 'even in the absence of meaningful climate policy'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    7521,
#    7540): ([('wm/property/common_understanding', 0.8730589747428894),
#     None,
#     None,
#     None], "That's the good news"),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    7547,
#    7585): ([('wm/property/right_to_use', 0.9495186805725098),
#     None,
#     None,
#     None], 'it is not, in the end, simple good news'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    7616,
#    7676): ([('wm/process/extraction', 0.8149733543395996),
#     None,
#     None,
#     None], 'corresponding good news in all the other sectors of emissions'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    8068,
#    8073): ([('wm/concept/humanitarian_assistance/non_food_items',
#      1.199434757232666),
#     None,
#     None,
#     None], 'bucket'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd', 8203, 8221): (None,
#    'negative emissions)'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    8573,
#    8611): ([('wm/concept/innovation', 1.018442988395691),
#     None,
#     None,
#     None], 'next generation of more advanced models'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    8573,
#    8734): ([('wm/concept/environment/meteorology/temperature', 1.0),
#     None,
#     ('wm/process/breeding', 1.4562797546386719),
#     None], 'next generation of more advanced models are currently being developed to better predict what amount of temperature rise would result from certain emissions levels'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    8666,
#    8691): ([('wm/concept/environment/meteorology/temperature', 1.0),
#     ('wm/property/price_or_cost', 1.0690785646438599),
#     None,
#     None], 'amount of temperature rise'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    8741,
#    8791): ([('wm/concept/entity/people', 0.8576390147209167),
#     ('wm/property/stability', 0.9717144966125488),
#     ('wm/process/training/training', 0.8344540596008301),
#     None], 'while the models are by no means speaking in unison'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    8796,
#    8825): ([('wm/property/shortage', 0.9299516677856445),
#     None,
#     None,
#     None], 'concerning proportion of those'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    8865,
#    8871): ([('wm/property/geographic_resolution/global', 0.9184470772743225),
#     None,
#     None,
#     None], 'climate'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    8913,
#    8921): ([('wm/property/efficiency_or_efficacy', 0.8898687958717346),
#     None,
#     None,
#     None], 'emissions'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    8988,
#    8999): ([('wm/property/stability', 1.027764081954956),
#     None,
#     None,
#     None], 'better place'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    9119,
#    9134): ([('wm/property/price_or_cost', 1.0099023580551147),
#     None,
#     None,
#     None], 'higher emissions'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    9141,
#    9178): ([('wm/property/stability', 0.9803890585899353),
#     None,
#     None,
#     None], 'perhaps, in theory, even a worse place'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd', 9271, 9292): (None,
#    'our high-end estimates'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    9386,
#    9497): ([('wm/concept/economy/budget', 1.0),
#     None,
#     ('wm/process/observation', 0.8894603252410889),
#     None], 'As this animation usefully shows, we are practically already at the limit of our "carbon budget" for 1.5 degrees'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd', 9487, 9505): (None,
#    '1.5 degrees Celsius'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    9749,
#    9792): ([('wm/concept/environment/natural_resources/fossil_fuels',
#      1.6655217409133911),
#     None,
#     ('wm/process/flow', 0.7579807639122009),
#     ('wm/property/stability',
#      1.027018666267395)], 'never again emitting another ounce of carbon'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd', 9970, 9989): (None,
#    'not just 1.5 degrees'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    10206,
#    10307): ([('wm/concept/environment/climate', 1.0),
#     None,
#     ('wm/process/communication/ask/question', 1.1444419622421265),
#     None], 'This may all seem dizzyingly complicated on-the-one-hand-and-on-the-other inside baseball climate talk'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    10287,
#    10307): ([('wm/concept/environment/climate', 1.0),
#     None,
#     ('wm/process/communication/ask/question', 1.1444419622421265),
#     None], 'baseball climate talk'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    10314,
#    10331): ([('wm/concept/economy/commercial_farmers', 0.798058807849884),
#     None,
#     None,
#     None], 'four big takeaways'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    10547,
#    10566): ([('wm/property/geographic_resolution/global', 0.857661783695221),
#     None,
#     None,
#     None], 'challenge of warming'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    11253,
#    11287): ([('wm/process/hatching', 0.7256255149841309),
#     ('wm/property/geographic_resolution/national', 0.9240543246269226),
#     None,
#     None], 'major determinant of warming levels'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    11347,
#    11397): ([('wm/concept/environment/natural_resources/fossil_fuels',
#      1.6655217409133911),
#     ('wm/property/price_or_cost', 1.0690785646438599),
#     ('wm/process/consumption', 0.5565191507339478),
#     ('wm/property/stability',
#      1.0292072296142578)], 'that putting X amount of carbon into the atmosphere'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    11412,
#    11458): ([('wm/concept/entity/locations/urban_area', 0.8551421165466309),
#     None,
#     ('wm/process/communication/ask', 0.7620482444763184),
#     None], 'Y amount of warming on a timescale of a century'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    11559,
#    11595): ([('wm/concept/goods/minerals', 0.8200423717498779),
#     None,
#     ('wm/process/training/agriculture_extension', 0.7622754573822021),
#     None], "Whether China's coal use grows slowly"),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    11598,
#    11758): ([('wm/concept/time/late_onset', 0.8694588541984558),
#     None,
#     ('wm/process/farming/herding', 0.6756770610809326),
#     None], 'plateaus and then drops slowly, or drops precipitously over the next two decades - that is not something it is even possible to know, really, though we can guess'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    12288,
#    12315): ([('wm/process/depreciation', 0.5958523154258728),
#     ('wm/property/price_or_cost', 1.0298583507537842),
#     None,
#     None], 'sixfold increase in coal use'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    12308,
#    12315): ([('wm/property/usefulness', 0.9923022985458374),
#     None,
#     None,
#     None], 'coal use'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    12678,
#    12685): ([('wm/property/stability', 0.9373384714126587),
#     None,
#     None,
#     None], 'no point'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    12829,
#    12863): ([('wm/process/farming/irrigation', 0.771620512008667),
#     ('wm/property/stability', 0.9617336988449097),
#     None,
#     None], 'more of the powerful greenhouse gas'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    12829,
#    12920): ([('wm/concept/entity/locations/country', 1.0),
#     None,
#     ('wm/process/consumption', 0.8641990423202515),
#     None], 'more of the powerful greenhouse gas than the entire oil and gas industries of many countries'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13085,
#    13128): ([('wm/property/common_understanding', 1.1443686485290527),
#     None,
#     None,
#     None], 'their understanding on what level of warming'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13108,
#    13128): ([('wm/property/stability', 0.9733248949050903),
#     None,
#     None,
#     None], 'what level of warming'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13113,
#    13128): ([('wm/property/stability', 0.8887057900428772),
#     None,
#     None,
#     None], 'level of warming'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13224,
#    13246): ([('wm/concept/information/misinformation', 0.8439232110977173),
#     ('wm/property/price_or_cost', 1.0446996688842773),
#     ('wm/process/access', 0.8590467572212219),
#     None], 'less alarmist direction'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13249,
#    13258): ([('wm/concept/entity/people/adviser', 1.5973329544067383),
#     None,
#     None,
#     None], 'Scientists'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13317,
#    13328): ([('wm/concept/entity/hamas', 0.5023889541625977),
#     ('wm/property/usefulness', 0.8701587319374084),
#     None,
#     None], 'using RCP8.5'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd', 13349, 13358): (None, 'no policy"'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13376,
#    13402): ([('wm/concept/environment/climate', 1.0),
#     ('wm/property/aftermath', 0.858471691608429),
#     None,
#     None], 'usual" climate trajectories'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13424,
#    13442): ([('wm/property/common_understanding', 0.8993669152259827),
#     None,
#     None,
#     None], 'describing research'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13435,
#    13442): ([('wm/property/common_understanding', 0.88165283203125),
#     None,
#     None,
#     None], 'research'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13489,
#    13500): ([('wm/property/geographic_resolution/global', 1.0802714824676514),
#     None,
#     None,
#     None], 'usual" world'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13796,
#    13820): ([('wm/property/volatility', 1.7396910190582275),
#     None,
#     None,
#     None], 'face of great uncertainty'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    13967,
#    13991): ([('wm/property/stability', 0.9206315875053406),
#     None,
#     None,
#     None], 'positive or happy outcome'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    14134,
#    14147): ([('wm/concept/population_demographics/population_density/de-population',
#      0.7967486381530762),
#     None,
#     None,
#     None], 'sea-level rise'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    14234,
#    14249): ([('wm/property/widespread', 1.0618946552276611),
#     None,
#     None,
#     None], 'many millions of'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    14598,
#    14603): ([('wm/property/drug_resistance', 0.8678146600723267),
#     None,
#     None,
#     None], 'strain'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    14810,
#    14844): ([('wm/property/right_to_use', 0.8942840099334717),
#     None,
#     None,
#     None], 'that these "ndings do not, actually'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    15026,
#    15066): ([('wm/property/preparedness', 0.8769559264183044),
#     None,
#     None,
#     None], 'not from some projected scenario backward'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    15454,
#    15458): ([('wm/property/geographic_resolution/global', 1.9016761779785156),
#     None,
#     None,
#     None], 'world'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    15512,
#    15520): ([('wm/property/efficiency_or_efficacy', 0.8898687958717346),
#     None,
#     None,
#     None], 'emissions'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    15654,
#    15753): ([('wm/concept/environment/climate', 0.9361006021499634),
#     None,
#     None,
#     None], 'emissions by 7.6 percent per year every year for the next decade, globally, to hit the Paris targets'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    15741,
#    15753): ([('wm/concept/economy/tourism', 0.9084384441375732),
#     ('wm/property/preparedness', 0.8729010820388794),
#     None,
#     None], 'Paris targets'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    15863,
#    15922): ([('wm/concept/entity/locations/country', 1.0),
#     None,
#     ('wm/process/population', 1.1113851070404053),
#     None], 'many countries with populations collectively in the billions'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd', 16124, 16154): (None,
#    'perhaps the most signi"cant one'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    16161,
#    16220): ([('wm/concept/environment/climate', 1.0),
#     None,
#     ('wm/process/start', 0.9266386032104492),
#     None], 'even in a year of dramatic political mobilization on climate'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    16291,
#    16308): ([('wm/property/stability', 1.036007285118103),
#     None,
#     None,
#     None], 'one major response'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    17814,
#    17814): ([('wm/process/communication/ask', 0.8085198402404785),
#     None,
#     None,
#     None], 'o'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    17821,
#    17827): ([('wm/process/sharing', 0.7062708139419556),
#     None,
#     None,
#     None], 'smiling'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    18064,
#    18257): ([('wm/concept/population_demographics/religion', 0.90233314037323),
#     ('wm/property/stability', 0.9169420003890991),
#     None,
#     None], 'Right," I said, "I don\'t think human extinction or total civilization collapse is likely, though the pressures are going to get pretty intense and we don\'t really know how societies will respond'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    18095,
#    18110): ([('wm/process/eradication', 1.672783374786377),
#     ('wm/property/common_understanding', 0.9146566390991211),
#     None,
#     None], 'human extinction'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    18115,
#    18141): ([('wm/concept/population_demographics/religion', 0.90233314037323),
#     ('wm/property/aftermath', 0.9523909687995911),
#     None,
#     None], 'total civilization collapse'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    18165,
#    18173): ([('wm/property/volatility', 0.8628477454185486),
#     None,
#     None,
#     None], 'pressures'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    18211,
#    18257): ([('wm/property/stability', 1.0509308576583862),
#     None,
#     None,
#     None], "we don't really know how societies will respond"),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    18801,
#    18938): ([('wm/concept/environment/pollution', 1.0),
#     ('wm/property/geographic_resolution/global', 1.9016761779785156),
#     None,
#     None], 'air pollution, which were today concentrated in India and China and would likely grow in other areas of the developing world in the future'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    19008,
#    19040): ([('wm/property/right_to_use', 0.8756127953529358),
#     None,
#     None,
#     None], 'not that bad, relatively speaking'),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    19072,
#    19095): ([('wm/property/stability', 1.0509308576583862),
#     None,
#     None,
#     None], "I didn't have the chance"),
#   ('0a6200447248b0bfb4a67d0fb5e84cbd',
#    19767,
#    19775): ([('wm/property/right_to_use', 0.9127533435821533),
#     None,
#     None,
#     None], 'long time'),
#   ('0a05a0cf639f256798ba50894c031923',
#    212,
#    249): ([('wm/concept/entity/hamas', 0.7469273805618286),
#     ('wm/property/diversity', 0.9869760274887085),
#     ('wm/process/conflict/protest_or_demonstration', 0.7957261800765991),
#     ('wm/property/geographic_resolution/local',
#      0.918201744556427)], 'central and southern areas of Ethiopia'),
#   ('0a05a0cf639f256798ba50894c031923',
#    483,
#    523): ([('wm/concept/health/biometrics', 1.6126959323883057),
#     None,
#     ('wm/process/grouping', 0.8003578782081604),
#     None], 'random amplified polymorphic DNA patterns'),
#   ('0a05a0cf639f256798ba50894c031923', 526, 540): (None, 'BglI ribotyping'),
#   ('0a05a0cf639f256798ba50894c031923',
#    546,
#    573): ([('wm/property/drug_resistance', 1.3112025260925293),
#     None,
#     None,
#     None], 'antimicrobial susceptibility'),
#   ('0a05a0cf639f256798ba50894c031923',
#    598,
#    625): ([('wm/concept/health/biometrics', 1.6126959323883057),
#     None,
#     ('wm/process/extraction', 0.7149844765663147),
#     ('wm/property/diversity',
#      0.9983280897140503)], 'unique amplified DNA pattern'),
#   ('0a05a0cf639f256798ba50894c031923', 633, 654): (None,
#    'prevalent ribotype B8a'),
#   ('00c4da721db4804cf56c3ffdca6f9d2e',
#    266,
#    289): ([('wm/concept/goods/medicine', 1.2869378328323364),
#     ('wm/property/usefulness', 0.9923022985458374),
#     ('wm/process/research', 1.1716091632843018),
#     ('wm/property/widespread',
#      1.0096060037612915)], 'Most studies on drug use'),
#   ('00c4da721db4804cf56c3ffdca6f9d2e',
#    1667,
#    1727): ([('wm/concept/intervention', 0.8839068412780762),
#     ('wm/property/stability', 1.0509308576583862),
#     None,
#     None], 'Only few (4.2%) of the participants did not mind taking drugs'),
#   ('00c4da721db4804cf56c3ffdca6f9d2e', 1763, 1767): (None, '(90%)'),
#   ('00c4da721db4804cf56c3ffdca6f9d2e',
#    1897,
#    1911): ([('wm/property/price_or_cost', 1.0446996688842773),
#     None,
#     None,
#     None], 'less likelihood'),
#   ('00c4da721db4804cf56c3ffdca6f9d2e',
#    2205,
#    2223): ([('wm/process/training/training', 0.8953113555908203),
#     ('wm/property/adequacy', 1.1922171115875244),
#     None,
#     None], 'Adequate counseling'),
#   ('00c4da721db4804cf56c3ffdca6f9d2e',
#    2205,
#    2398): ([('wm/concept/health/healthcare', 1.0),
#     None,
#     ('wm/process/provision', 1.2326343059539795),
#     None], "Adequate counseling has to be provided by physicians, pharmacists, and other healthcare professionals to change pregnant women's conservative attitudes and misinformed beliefs on medication risk"),
#   ('00c4da721db4804cf56c3ffdca6f9d2e',
#    2307,
#    2398): ([('wm/concept/entity/people/women', 1.0),
#     None,
#     ('wm/process/population/birth', 0.9465526342391968),
#     ('wm/property/stability',
#      1.0192785263061523)], "to change pregnant women's conservative attitudes and misinformed beliefs on medication risk"),
#   ('00c4da721db4804cf56c3ffdca6f9d2e',
#    2317,
#    2355): ([('wm/concept/entity/people/women', 1.0),
#     None,
#     ('wm/process/population/birth', 0.9465526342391968),
#     None], "pregnant women's conservative attitudes"),
#   ('00c4da721db4804cf56c3ffdca6f9d2e',
#    2361,
#    2379): ([('wm/process/communication/deception', 1.0547653436660767),
#     ('wm/property/common_understanding', 0.8621959686279297),
#     None,
#     None], 'misinformed beliefs'),
#   ('00c4da721db4804cf56c3ffdca6f9d2e',
#    2384,
#    2398): ([('wm/concept/goods/medicine', 1.8041163682937622),
#     ('wm/property/risk', 1.0),
#     None,
#     None], 'medication risk'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    1515,
#    1579): ([('wm/process/communication/description', 0.8854642510414124),
#     ('wm/property/stability', 1.0509308576583862),
#     None,
#     None], 'that the victims did not want to make any statements to the media'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    2193,
#    2215): ([('wm/property/geographic_resolution/international', 1.0),
#     None,
#     None,
#     None], 'international community'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    2249,
#    2303): ([('wm/concept/entity/hamas', 0.7211836576461792),
#     ('wm/property/stability', 0.9427043199539185),
#     ('wm/process/conflict/defeat', 1.0418120622634888),
#     ('wm/property/geographic_resolution/local',
#      1.0149891376495361)], 'destabilizing role of the Eritrean regime in the region'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    2433,
#    2448): ([('wm/process/flow', 0.862347424030304),
#     ('wm/property/violent', 0.9181629419326782),
#     None,
#     None], 'its intense heat'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    2590,
#    2663): ([('wm/process/conflict/tribal_conflict', 0.5775337815284729),
#     ('wm/property/widespread', 1.0090585947036743),
#     None,
#     None], "three people in Ethiopia's capital, all of whom asked not to be identified"),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    2677,
#    2687): ([('wm/concept/information', 1.2869517803192139),
#     None,
#     None,
#     None], 'information'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    3064,
#    3099): ([('wm/process/communication/opposition', 0.7655634880065918),
#     ('wm/property/stability', 0.9733248949050903),
#     None,
#     None], 'that it deeply regrets what happened'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    3087,
#    3099): ([('wm/property/stability', 0.9733248949050903),
#     None,
#     None,
#     None], 'what happened'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    3224,
#    3300): ([('wm/concept/economy/tourism', 0.8316771984100342),
#     None,
#     ('wm/process/communication/ask/question', 1.0),
#     None], 'no indications that the security of guests could be in question in the region'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    3335,
#    3358): ([('wm/process/travel', 1.0),
#     ('wm/property/security', 0.8726761937141418),
#     None,
#     None], 'no German travel warning'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    4115,
#    4154): ([('wm/concept/entity/government_entity', 1.6292777061462402),
#     None,
#     ('wm/process/travel', 1.0),
#     None], 'Austrian Foreign Ministry travel warning'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    4204,
#    4256): ([('wm/concept/economy/tourism', 1.365678071975708),
#     None,
#     ('wm/process/conflict/attack', 1.0),
#     None], 'several incidents involving attacks on tourist groups'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    4721,
#    4737): ([('wm/property/preparedness', 0.8870962858200073),
#     None,
#     None,
#     None], 'no infrastructure'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    4752,
#    4769): ([('wm/process/communication', 0.8439412117004395),
#     None,
#     None,
#     None], 'no telephone lines'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    4889,
#    4934): ([('wm/concept/infrastructure/communication', 0.9341124892234802),
#     ('wm/property/widespread', 0.9098372459411621),
#     ('wm/process/publication', 0.9687462449073792),
#     None], 'Associated Press writers George Jahn in Vienna'),
#   ('0a1e66c6f42dbeba261b39f5ce36549a',
#    5049,
#    5054): ([('wm/property/aftermath', 0.876968264579773),
#     None,
#     None,
#     None], 'report'),
#   ('0a703d8615b35dd67df8d4e86e029a1f',
#    31,
#    59): ([('wm/concept/goods/medicine', 1.0),
#     None,
#     ('wm/process/enhancement', 0.7521803975105286),
#     None], 'Though use of herbal medicine'),
#   ('0a703d8615b35dd67df8d4e86e029a1f',
#    99,
#    222): ([('wm/concept/environment/pollution', 1.0),
#     None,
#     ('wm/process/farming/planting', 1.3351569175720215),
#     None], 'environmental pollution especially with heavy metals poses serious problem on quality of medicinal plants and their products'),
#   ('0a703d8615b35dd67df8d4e86e029a1f',
#    336,
#    355): ([('wm/property/alternative', 0.8557837605476379),
#     None,
#     None,
#     None], 'traditional medicine'),
#   ('0a703d8615b35dd67df8d4e86e029a1f',
#    366,
#    393): ([('wm/concept/goods/agricultural/seed', 0.9603196382522583),
#     ('wm/property/stability', 0.8887057900428772),
#     ('wm/process/destocking', 0.8498953580856323),
#     None], 'heavy metals level of plants'),
#   ('0a0a7f504d471202fe61e1dda9e1fd94',
#    371,
#    398): ([('wm/concept/entity/hamas', 0.7469273805618286),
#     ('wm/property/widespread', 1.0096060037612915),
#     None,
#     None], 'most widely used in Ethiopia'),
#   ('0a0a7f504d471202fe61e1dda9e1fd94',
#    489,
#    501): ([('wm/property/preparedness', 1.002453088760376),
#     None,
#     None,
#     None], 'little effort'),
#   ('0a0a7f504d471202fe61e1dda9e1fd94',
#    1862,
#    1938): ([('wm/concept/health/disease/malaria', 1.0),
#     None,
#     ('wm/process/access', 1.0),
#     None], 'Improving logistics access for malaria microscopy at all level of health care'),
#   ('0a0a7f504d471202fe61e1dda9e1fd94',
#    1965,
#    1985): ([('wm/property/adequacy', 0.8505513668060303),
#     None,
#     None,
#     None], 'accuracy of diagnosis'),
#   ('0a0a7f504d471202fe61e1dda9e1fd94',
#    1991,
#    2025): ([('wm/concept/health/disease/malaria', 1.0),
#     None,
#     ('wm/process/flow', 0.7407100200653076),
#     None], 'quantification of malaria parasites'),
#   ('0a0a7f504d471202fe61e1dda9e1fd94',
#    2067,
#    2074): ([('wm/property/common_understanding', 0.88165283203125),
#     None,
#     None,
#     None], 'research'),
#   ('0a0a7f504d471202fe61e1dda9e1fd94',
#    2098,
#    2210): ([('wm/process/training/training', 1.0),
#     ('wm/property/quality', 1.0),
#     None,
#     None], 'continued training and regular supervision of the staff and implementation of quality control program in the area'),
#   ('0a0a7f504d471202fe61e1dda9e1fd94',
#    2121,
#    2139): ([('wm/process/consumption', 0.8148902654647827),
#     ('wm/property/accountability', 0.8615879416465759),
#     None,
#     None], 'regular supervision'),
#   ('0a98ea0281b18f0e533056e2b1f24587', 75, 114): (None,
#    'order, worth $1.1 billion at list prices'),
#   ('0a98ea0281b18f0e533056e2b1f24587',
#    149,
#    189): ([('wm/concept/entity/drone', 0.751781702041626),
#     ('wm/property/price_or_cost', 0.8797568082809448),
#     ('wm/process/conflict/abduction', 0.7227799892425537),
#     None], "unidentified customer on Boeing's website"),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    279,
#    319): ([('wm/concept/entity/locations/urban_area', 0.9772312045097351),
#     None,
#     None,
#     None], "Ethiopian capital's poorest neighbourhood"),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    350,
#    474): ([('wm/concept/goods/water', 1.0),
#     None,
#     ('wm/process/cleaning', 1.8337483406066895),
#     None], "it didn't have any clean water until the Canadian government financed the installation of a network of water pipes and drains"),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    391,
#    409): ([('wm/concept/economy/currency', 0.800822377204895),
#     ('wm/property/foreign', 1.0047434568405151),
#     None,
#     None], 'Canadian government'),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    579,
#    630): ([('wm/process/disguise', 0.7538648247718811),
#     ('wm/property', 0.9670293927192688),
#     None,
#     None], 'small homes with mud walls and corrugated iron roofs'),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    636,
#    728): ([('wm/concept/entity/locations/country', 1.0),
#     ('wm/property/geographic_resolution/global', 1.9016761779785156),
#     None,
#     None], "Ethiopia is one of the world's poorest countries, with an average annual income of about $300"),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    694,
#    728): ([('wm/concept/economy/income', 1.0),
#     ('wm/property/price_or_cost', 0.8806873559951782),
#     None,
#     None], 'average annual income of about $300'),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    739,
#    761): ([('wm/concept/health/life', 1.0),
#     None,
#     ('wm/process/hatching', 0.8300517201423645),
#     None], 'average life expectancy'),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    954,
#    965): ([('wm/concept/population_demographics/tribe', 0.8815663456916809),
#     None,
#     ('wm/process/travel', 1.0998303890228271),
#     None], 'African tour'),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    1170,
#    1204): ([('wm/concept/entity/hamas', 0.48204484581947327),
#     None,
#     ('wm/process/transportation/personal_transportation', 0.6839357614517212),
#     None], 'Ontario Liberal MPs Mauril Belanger'),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    1504,
#    1523): ([('wm/concept/economy/currency', 0.800822377204895),
#     ('wm/property/widespread', 0.9073563814163208),
#     ('wm/process/communication/warning', 0.7829381227493286),
#     None], 'Small Canadian flags'),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    1682,
#    1695): ([('wm/property/carrying_capacity', 0.9094847440719604),
#     None,
#     None,
#     None], 'small children'),
#   ('0a7c1bfda4ebdae8e2ef3932195744c2',
#    1995,
#    2001): ([('wm/property/foreign', 1.0295581817626953),
#     None,
#     None,
#     None], 'new aid'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    256,
#    304): ([('wm/concept/crisis_or_disaster/natural_disaster/earthquake',
#      0.9472448229789734),
#     None,
#     ('wm/process/flow', 0.6796546578407288),
#     ('wm/property/widespread',
#      0.9984342455863953)], 'Seismic anisotropy has increasingly been proposed'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    550,
#    564): ([('wm/concept/crisis_or_disaster/conflict/hostility',
#      0.788939356803894),
#     ('wm/property/chronic', 0.8550514578819275),
#     None,
#     None], 'Afar depression'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    1223,
#    1246): ([('wm/concept/crisis_or_disaster/natural_disaster/environmental_degradation',
#      0.8400343656539917),
#     ('wm/property/price_or_cost', 0.9902451038360596),
#     ('wm/process/mining', 0.5987244248390198),
#     None], 'lower crustal seismicity'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    1274,
#    1345): ([('wm/concept/environment/natural_resources/fresh_water_bodies/pond_or_reservoir',
#      1.8636314868927002),
#     None,
#     ('wm/process/inflation', 1.0),
#     None], 'inflation of a lower crustal magma reservoir in the Manda-Hararo segment'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    1348,
#    1420): ([('wm/concept/crisis_or_disaster/natural_disaster/environmental_degradation',
#      0.686248242855072),
#     None,
#     ('wm/process/observation', 1.143890380859375),
#     ('wm/property/common_understanding',
#      1.0220189094543457)], 'This is the only clearly observed precursory change in seismic anisotropy'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    1454,
#    1484): ([('wm/concept/crisis_or_disaster/natural_disaster/environmental_degradation',
#      0.686248242855072),
#     None,
#     ('wm/process/mitigation', 0.808243989944458),
#     None], 'magnitude of seismic anisotropy'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    1505,
#    1575): ([('wm/process/stay_or_remain', 0.8833460211753845),
#     ('wm/property/widespread', 0.9170098900794983),
#     None,
#     None], 'before rapidly returning to predyke values once the intrusion has ended'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    1682,
#    1701): ([('wm/concept/environment/natural_resources/fresh_water_bodies/pond_or_reservoir',
#      1.8636314868927002),
#     None,
#     ('wm/process/flow', 0.767390251159668),
#     ('wm/property/deep', 1.0)], 'deep magma reservoir'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    1855,
#    1890): ([('wm/concept/goods/agricultural/irrigation_equipment',
#      0.9840899109840393),
#     ('wm/property/stability', 0.9488731622695923),
#     ('wm/process/combining', 1.4790737628936768),
#     None], 'strong evidence for a hydraulic link'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    1877,
#    1890): ([('wm/concept/goods/agricultural/irrigation_equipment',
#      0.9840899109840393),
#     None,
#     ('wm/process/combining', 1.4790737628936768),
#     None], 'hydraulic link'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    1904,
#    1954): ([('wm/concept/crisis_or_disaster/natural_disaster/volcanic_eruption',
#      0.9938086867332458),
#     ('wm/property/deep', 1.0),
#     ('wm/process/inhabiting_or_occupancy', 0.7750512957572937),
#     ('wm/property/security',
#      0.9056635499000549)], 'deep magma systems of the neighboring rift segments'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    2202,
#    2222): ([('wm/property/stability', 1.0989291667938232),
#     None,
#     None,
#     None], 'to be a powerful tool'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    2482,
#    2498): ([('wm/property/stability', 0.8504835963249207),
#     None,
#     None,
#     None], 'Solid Earth, 2018'),
#   ('00cc94296fe1f2021782a6128e22bbfa',
#    2552,
#    2562): ([('wm/property/stability', 0.8504835963249207),
#     None,
#     None,
#     None], 'Solid Earth'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    239,
#    259): ([('wm/process/population/birth', 1.0),
#     ('wm/property/risk', 1.007085919380188),
#     None,
#     None], 'Adverse birth outcome'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    239,
#    356): ([('wm/concept/health/malnutrition', 0.847159743309021),
#     None,
#     ('wm/process/population/birth', 1.0),
#     None], 'Adverse birth outcome which attributes to most perinatal deaths is an important indicator of child health and survival'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    281,
#    301): ([('wm/process/population/death', 1.1724909543991089),
#     None,
#     None,
#     None], 'most perinatal deaths'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    918,
#    933): ([('wm/process/population/birth', 1.0),
#     ('wm/property/price_or_cost', 1.0189886093139648),
#     None,
#     None], 'low birth weight'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    1577,
#    1612): ([('wm/concept/entity/people/maternal', 0.816050112247467),
#     None,
#     ('wm/process/combining', 0.8007829189300537),
#     ('wm/property/price_or_cost',
#      1.0446996688842773)], 'less than four antenatal care visits'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    1646,
#    1980): ([('wm/concept/population_demographics/clan', 1.8508837223052979),
#     None,
#     ('wm/process/planning', 1.0),
#     None], 'not receiving dietary counseling [AOR=11.24, 95% CI: 3.92-36.60], not using family planning methods [AOR=4.06, 95% CI:1.35-17.34], less than 24 months inter pregnancy interval [AOR=5.21, 95% CI: 1.89-13.86], and less than 11 g/dl hemoglobin level [AOR=4.86, 95% CI: 1.83-14.01] were significantly associated with adverse birth outcomes'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    1712,
#    1871): ([('wm/concept/population_demographics/clan', 1.8508837223052979),
#     None,
#     ('wm/process/planning', 1.0),
#     None], 'not using family planning methods [AOR=4.06, 95% CI:1.35-17.34], less than 24 months inter pregnancy interval [AOR=5.21, 95% CI: 1.89-13.86], and less than 11 g'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    1777,
#    1820): ([('wm/concept/entity/people/maternal', 0.942876935005188),
#     None,
#     None,
#     None], 'less than 24 months inter pregnancy interval'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    1858,
#    1891): ([('wm/concept/health/nutrients', 0.845694899559021),
#     ('wm/property/stability', 0.8887057900428772),
#     None,
#     None], 'less than 11 g/dl hemoglobin level'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    2057,
#    2088): ([('wm/concept/health/nutrition', 1.2265733480453491),
#     None,
#     ('wm/process/provision', 0.8678702712059021),
#     ('wm/property/stability',
#      1.0509308576583862)], 'not receiving dietary counseling'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    2130,
#    2159): ([('wm/process/start', 0.9187710285186768),
#     None,
#     None,
#     None], 'short inter-pregnancy interval'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    2166,
#    2185): ([('wm/concept/health/nutrients', 0.845694899559021),
#     ('wm/property/price_or_cost', 1.0189886093139648),
#     None,
#     None], 'low hemoglobin level'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    2317,
#    2348): ([('wm/process/communication/campaign', 1.0006407499313354),
#     ('wm/property/stability', 1.0989291667938232),
#     None,
#     None], 'concerted effort should be taken'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    2358,
#    2376): ([('wm/concept/population_demographics/clan', 1.8508837223052979),
#     None,
#     ('wm/process/planning', 1.0),
#     None], 'family planning use'),
#   ('0a03424de759fa0b8ccf9ace551af764',
#    2463,
#    2484): ([('wm/process/population/birth', 1.0),
#     ('wm/property/risk', 1.007085919380188),
#     None,
#     None], 'adverse birth outcomes'),
#   ('0a50b80b7039baecfceb37d3fe27a687',
#    273,
#    288): ([('wm/concept/health/injury', 1.8557000160217285),
#     ('wm/property/drug_resistance', 0.9840998649597168),
#     None,
#     None], 'Wound infections'),
#   ('0a50b80b7039baecfceb37d3fe27a687',
#    310,
#    356): ([('wm/concept/health/morbidity', 1.0),
#     ('wm/property/foreign', 1.0341817140579224),
#     None,
#     None], 'morbidity and mortality in developing countries'),
#   ('0a50b80b7039baecfceb37d3fe27a687', 1082, 1086): (None, '72.6%'),
#   ('0a50b80b7039baecfceb37d3fe27a687',
#    1463,
#    1514): ([('wm/concept/agriculture/pest/locust', 0.5508557558059692),
#     None,
#     ('wm/process/transaction', 0.6190324425697327),
#     ('wm/property/price_or_cost',
#      1.031987190246582)], 'MDR rate of gram positive and gram negative isolates'),
#   ('0a50b80b7039baecfceb37d3fe27a687',
#    1620,
#    1670): ([('wm/concept/environment/meteorology/relative_humidity',
#      0.979537844657898),
#     None,
#     ('wm/process/management', 1.0),
#     None], 'inadequate management of moisture, exudate or edema'),
#   ('0a50b80b7039baecfceb37d3fe27a687',
#    2492,
#    2538): ([('wm/concept/infrastructure/communication', 0.8756092190742493),
#     ('wm/property/geographic_resolution/international', 1.0),
#     ('wm/process/mitigation', 0.6824131011962891),
#     ('wm/property/price_or_cost',
#      0.9902451038360596)], 'International Journal of Lower Extremity Wounds'),
#   ('0a50b80b7039baecfceb37d3fe27a687',
#    2891,
#    2941): ([('wm/concept/infrastructure/communication', 0.8756092190742493),
#     ('wm/property/geographic_resolution/international', 1.0),
#     ('wm/process/mitigation', 0.6824131011962891),
#     ('wm/property/price_or_cost',
#      0.9902451038360596)], 'The International Journal of Lower Extremity Wounds'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    625,
#    629): ([('wm/concept/environment/meteorology/precipitation',
#      1.416393756866455),
#     None,
#     None,
#     None], 'rains'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    639,
#    671): ([('wm/concept/economy/small_farmers', 1.8935561180114746),
#     None,
#     ('wm/process/stay_or_remain', 0.8251703977584839),
#     ('wm/property/price_or_cost',
#      0.9696333408355713)], 'farmers lost their standing crops'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    738,
#    744): ([('wm/property/fallow', 0.9011510014533997),
#     None,
#     None,
#     None], 'pasture'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    750,
#    754): ([('wm/process/farming/irrigation', 1.0549311637878418),
#     None,
#     None,
#     None], 'water'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    826,
#    839): ([('wm/property/shortage', 1.2611445188522339),
#     None,
#     None,
#     None], 'food shortages'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    1003,
#    1077): ([('wm/property/widespread', 0.8518728017807007),
#     None,
#     None,
#     None], '3,500 severely malnourished children from six of the worst affected kebeles'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    1110,
#    1116): ([('wm/property/widespread', 0.9233989715576172),
#     None,
#     None,
#     None], 'problem'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    1273,
#    1317): ([('wm/concept/entity/people/child_or_youth', 0.9898992776870728),
#     None,
#     None,
#     None], 'severely and moderately malnourished children'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    1323,
#    1434): ([('wm/concept/entity/people/household', 1.0),
#     None,
#     ('wm/process/population/birth', 0.9465526342391968),
#     None], 'about 8,600 of the most affected people, including pregnant and lactating mothers and female heads of households'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    1443,
#    1460): ([('wm/property/price_or_cost', 1.007371425628662),
#     None,
#     None,
#     None], 'higher food prices'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    1532,
#    1572): ([('wm/property/right_to_use', 0.8769389390945435),
#     None,
#     None,
#     None], "It's not just about children being hungry"),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    1742,
#    1755): ([('wm/process/damage', 0.6382439732551575),
#     None,
#     None,
#     None], 'malnourishment'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    1766,
#    1804): ([('wm/concept/health/poor_childrens_health', 1.6235682964324951),
#     None,
#     ('wm/process/development', 1.0),
#     None], 'stunting and poor cognitive development'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    1812,
#    1819): ([('wm/concept/entity/people/child_or_youth', 1.7877399921417236),
#     None,
#     None,
#     None], 'children'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    2182,
#    2217): ([('wm/concept/entity/locations/country', 1.0),
#     ('wm/property/preparedness', 0.9336100220680237),
#     None,
#     None], 'effective responses across countries'),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    2587,
#    2629): ([('wm/process/training/agriculture_extension', 0.7622754573822021),
#     ('wm/property/geographic_resolution/global', 1.9016761779785156),
#     None,
#     None], "world's poorest and most vulnerable survive"),
#   ('00d6ff35e5a04d7d2a65f9748baaf5f3',
#    2682,
#    2771): ([('wm/concept/entity/organization', 1.0),
#     ('wm/property/geographic_resolution/global', 1.9016761779785156),
#     None,
# ...
#     ('wm/property/price_or_cost', 1.0),
#     None,
#     None], 'price of maize'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18263,
#    18273): ([('wm/concept/goods/food/protein_foods', 0.6358230113983154),
#     None,
#     ('wm/process/farming/harvesting', 0.4697679579257965),
#     None], 'wheat flour'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18319,
#    18338): ([('wm/concept/agriculture/crop/cereal_crops', 0.7118412256240845),
#     ('wm/property/price_or_cost', 1.0),
#     ('wm/process/population/death', 0.48007291555404663),
#     None], 'rising cereal prices'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18344,
#    18365): ([('wm/concept/agriculture/livestock', 1.0),
#     ('wm/property/price_or_cost', 1.0),
#     None,
#     None], 'lower livestock prices'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18368,
#    18401): ([('wm/concept/agriculture/livestock', 1.0),
#     None,
#     ('wm/process/trade', 1.0),
#     None], 'livestock to cereal Terms of Trade'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18432,
#    18465): ([('wm/concept/humanitarian_assistance/food_aid', 1.0),
#     None,
#     ('wm/process/provision', 0.5590167045593262),
#     None], 'three rounds food aid distribution'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18498,
#    18548): ([('wm/concept/humanitarian_assistance/food_aid', 1.0),
#     None,
#     ('wm/process/start', 0.5308164358139038),
#     None], 'only the first round of emergency food aid and PSNP'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18601,
#    18621): ([('wm/concept/economy/marketing', 0.5561056733131409),
#     None,
#     ('wm/process/stalling', 0.7838925123214722),
#     None], 'delay in distribution'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18659,
#    18671): ([('wm/concept/agriculture/crop/cereal_crops', 0.7118412256240845),
#     ('wm/property/price_or_cost', 1.0),
#     None,
#     None], 'cereal prices'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18689,
#    18717): ([('wm/concept/entity/people/household', 1.0),
#     None,
#     None,
#     None], 'Poor and very poor households'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18810,
#    18847): ([('wm/concept/infrastructure/communication', 0.3437687158584595),
#     None,
#     ('wm/process/prediction', 0.41342437267303467),
#     None], 'average rains from October to December'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18976,
#    18986): ([('wm/concept/goods/food', 1.0),
#     None,
#     ('wm/process/access', 1.0),
#     None], 'food access'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    18989,
#    19036): ([('wm/concept/entity/people/household', 1.0),
#     None,
#     ('wm/process/attempt', 0.5157044529914856),
#     None], 'Poor and very poor households in Dassench Woreda'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    19203,
#    19240): ([('wm/concept/agriculture/livestock', 1.0),
#     None,
#     ('wm/process/trade/export', 1.0),
#     None], 'Both local and export livestock prices'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    19296,
#    19333): ([('wm/concept/infrastructure/communication', 0.31026774644851685),
#     None,
#     ('wm/process/start', 1.0),
#     None], 'will likely to start rise in September'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    19358,
#    19404): ([('wm/concept/entity/locations/coastal_area', 0.6038645505905151),
#     None,
#     ('wm/process/trade/export', 1.0),
#     None], 'export demand from the Middle East for the Hajj'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    19430,
#    19461): ([('wm/concept/environment/meteorology/precipitation',
#      0.8193332552909851),
#     None,
#     ('wm/process/hatching', 0.5107250213623047),
#     None], 'normal total Gu/Genna 2014 rains'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    19615,
#    19624): ([('wm/process/stay_or_remain', 0.5128904581069946),
#     None,
#     None,
#     None], 'most areas'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    19667,
#    19691): ([('wm/concept/agriculture/livestock', 1.0),
#     ('wm/property/condition', 0.9387773871421814),
#     None,
#     None], 'livestock body conditions'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    19696,
#    19707): ([('wm/property/productivity', 1.0),
#     None,
#     None,
#     None], 'productivity'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    19726,
#    19773): ([('wm/concept/entity/people/household', 1.0),
#     None,
#     ('wm/process/transaction', 0.7071036696434021),
#     None], "Households' income from livestock and milk sales"),
#   ('0a94f8c62f1291636f8a65840d914099',
#    19884,
#    19915): ([('wm/concept/agriculture/livestock', 1.0),
#     None,
#     ('wm/process/mitigation', 0.5374736189842224),
#     None], 'increased livestock productivity'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    19930,
#    20019): ([('wm/concept/entity/people/household', 1.0),
#     None,
#     ('wm/process/provision', 0.5886643528938293),
#     None], 'poor households to receive higher wages for labor and more gifts from better-offhouseholds'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    20036,
#    20053): ([('wm/concept/environment/climate_change/higher_temperatures',
#      0.5411682724952698),
#     None,
#     ('wm/process/prediction', 0.666111409664154),
#     None], 'anticipated higher'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    20048,
#    20094): ([('wm/concept/environment/climate_change/higher_temperatures',
#      0.5411682724952698),
#     None,
#     ('wm/process/mitigation', 0.5728117227554321),
#     None], 'higher than seasonal increases in cereal prices'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    20082,
#    20094): ([('wm/concept/agriculture/crop/cereal_crops', 0.7118412256240845),
#     ('wm/property/price_or_cost', 1.0),
#     None,
#     None], 'cereal prices'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    20119,
#    20129): ([('wm/concept/goods/food', 1.0),
#     None,
#     ('wm/process/access', 1.0),
#     None], 'food access'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    20157,
#    20166): ([('wm/concept/agriculture/livestock', 0.7336975932121277),
#     None,
#     ('wm/process/selection', 0.4280930757522583),
#     None], 'herd sizes'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    20197,
#    20206): ([('wm/process/farming/herding', 0.6052348613739014),
#     None,
#     None,
#     None], 'most herds'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    20290,
#    20303): ([('wm/concept/crisis_or_disaster/natural_disaster/drought',
#      0.5367652177810669),
#     None,
#     ('wm/process/selection', 0.4280930757522583),
#     None], 'low herd sizes'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    20318,
#    20420): ([('wm/concept/entity/people/household', 1.0),
#     None,
#     ('wm/process/transaction', 0.7071036696434021),
#     None], 'poor and very poor households to receive enough income from livestock sales and livestock product sales'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    20526,
#    20554): ([('wm/concept/entity/people/household', 1.0),
#     None,
#     None,
#     None], 'poor and very poor households'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    20743,
#    20760): ([('wm/process/hatching', 0.5107250213623047),
#     None,
#     None,
#     None], 'mostly normal time'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    20989,
#    21105): ([('wm/concept/crisis_or_disaster/natural_disaster/drought',
#      0.5413346886634827),
#     None,
#     None,
#     None], 'March and early April, the rains were of mostly near normal amounts and distribution, especially in Amhara and Tigray'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    21128,
#    21142): ([('wm/concept/crisis_or_disaster/natural_disaster/drought',
#      0.717706561088562),
#     None,
#     None,
#     None], 'normal rainfall'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    21176,
#    21182): ([('wm/concept/environment/natural_resources/land/pasture', 1.0),
#     None,
#     None,
#     None], 'pasture'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    21188,
#    21205): ([('wm/concept/goods/water', 1.0),
#     ('wm/property/availability', 1.0),
#     None,
#     None], 'water availability'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    21211,
#    21219): ([('wm/concept/agriculture/livestock', 1.0),
#     None,
#     None,
#     None], 'livestock'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    21301,
#    21305): ([('wm/concept/environment/meteorology/precipitation',
#      0.8193332552909851),
#     None,
#     None,
#     None], 'rains'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    21386,
#    21499): ([('wm/concept/time/belg', 1.0),
#     None,
#     ('wm/process/farming/planting', 0.8879470825195312),
#     None], 'about 80 percent of the average Belg planted area was already planted North and South Wollo Zones in Amhara Region'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    21611,
#    21641): ([('wm/concept/goods/agricultural/seed', 1.0),
#     ('wm/property/availability', 1.0),
#     None,
#     None], 'unusually low seed availability'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    21661,
#    21696): ([('wm/concept/environment/natural_resources/land/pasture',
#      0.5601335763931274),
#     None,
#     ('wm/process/start', 0.5137460827827454),
#     None], 'planting from reaching full coverage'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    21706,
#    21796): ([('wm/concept/entity/locations/urban_area', 0.5559109449386597),
#     None,
#     ('wm/process/research', 0.535732090473175),
#     None], 'other hand, planted area is only a little bit over 60 percent of average in parts of Tigray'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    21862,
#    21873): ([('wm/concept/entity/locations/urban_area', 0.5559109449386597),
#     None,
#     ('wm/process/farming/planting', 0.8879470825195312),
#     None], 'planted area'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    21929,
#    21936): ([('wm/process/farming/planting', 1.0),
#     None,
#     None,
#     None], 'planting'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    22077,
#    22154): ([('wm/concept/environment/meteorology/precipitation',
#      0.8193332552909851),
#     None,
#     ('wm/process/start', 1.0),
#     None], 'delay of the start of the rains in these areas or somewhat erratic performance'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    22177,
#    22196): ([('wm/concept/entity/locations/urban_area', 0.5559109449386597),
#     None,
#     ('wm/process/prediction', 0.41342437267303467),
#     None], 'average planted area'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    22342,
#    22384): ([('wm/concept/environment/natural_resources/land', 1.0),
#     None,
#     ('wm/process/preparation', 1.0),
#     None], 'Land preparation for long-cycle Meher crops'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    22397,
#    22408): ([('wm/process/farming/planting', 1.0),
#     None,
#     None,
#     None], 'and planting'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    22592,
#    22630): ([('wm/concept/crisis_or_disaster/conflict', 1.0),
#     None,
#     ('wm/process/access', 1.0),
#     None], 'no major conflicts over resource access'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    22663,
#    22691): ([('wm/concept/goods/water', 1.0),
#     ('wm/property/availability', 1.0),
#     None,
#     None], 'Forage and water availability'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    22776,
#    22814): ([('wm/concept/time/belg', 1.0),
#     None,
#     ('wm/process/stay_or_remain', 0.5374682545661926),
#     None], 'mostly normal performance of Belg rains'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    22830,
#    22849): ([('wm/concept/environment/natural_resources/land/pasture', 1.0),
#     ('wm/property/availability', 1.0),
#     None,
#     None], 'pasture availability'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    22853,
#    22870): ([('wm/concept/goods/water', 1.0),
#     ('wm/property/availability', 1.0),
#     None,
#     None], 'Water availability'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    22893,
#    22934): ([('wm/process/stay_or_remain', 0.5128904581069946),
#     None,
#     None,
#     None], 'most parts of East and West Hararghe Zones'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    22951,
#    22963): ([('wm/concept/entity/locations/lowland_area', 0.7515206933021545),
#     None,
#     None,
#     None], 'lowland areas'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    23104,
#    23165): ([('wm/concept/goods/water', 1.0),
#     None,
#     ('wm/process/remediation', 0.5706174373626709),
#     None], 'However, in West Hararghe Zone, water trucking recently ceased'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    23178,
#    23239): ([('wm/concept/goods/water', 1.0),
#     None,
#     ('wm/process/consumption', 1.0),
#     None], 'availability of water both for human and livestock consumption'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    23252,
#    23275): ([('wm/concept/agriculture/livestock', 1.0),
#     ('wm/property/condition', 0.9387773871421814),
#     None,
#     None], 'conditions for livestock'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    23321,
#    23345): ([('wm/concept/goods/water', 1.0),
#     None,
#     ('wm/process/hatching', 0.5107250213623047),
#     None], 'normal water availability'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    23492,
#    23604): ([('wm/concept/time/wet_season', 1.0),
#     None,
#     ('wm/process/farming/herding', 0.8608784079551697),
#     None], 'livestock have not been returned to their normal wet season grazing areas as water points are not yet replenished'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    23528,
#    23564): ([('wm/concept/time/wet_season', 1.0),
#     None,
#     ('wm/process/farming/herding', 0.8608784079551697),
#     None], 'their normal wet season grazing areas'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    23753,
#    23774): ([('wm/concept/entity/border', 0.5526479482650757),
#     None,
#     ('wm/process/conflict/resolution', 0.442144513130188),
#     None], 'Boundary demarcation p'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    23955,
#    24014): ([('wm/concept/entity/locations/urban_area', 0.6248953342437744),
#     None,
#     ('wm/process/start', 1.0),
#     None], 'However, this demarcation has not yet started in these areas'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    24103,
#    24262): ([('wm/concept/entity/people/migration/displaced_person', 1.0),
#     None,
#     ('wm/process/conflict', 1.0),
#     None], 'Internally displaced persons (IDPs) who fled the conflict in four kebeles of Meyu Muluke and six kebeles of Qumbi have not yet returned to their areas or origin'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    24276,
#    24287): ([('wm/concept/entity/people/migration/displaced_person',
#      0.5973207950592041),
#     None,
#     None,
#     None], 'displacement'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    24290,
#    24362): ([('wm/concept/time/belg', 1.0),
#     None,
#     ('wm/process/farming/planting', 1.0),
#     None], 'planting of both Belg and long-cycle Meher crops has not been on schedule'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    24374,
#    24414): ([('wm/concept/entity/locations/woreda', 1.0),
#     None,
#     ('wm/process/farming/planting', 0.8879470825195312),
#     None], 'near normal planted area in either woreda'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    24568,
#    24592): ([('wm/concept/government', 1.0),
#     None,
#     ('wm/process/attempt', 0.7903582453727722),
#     None], 'Efforts by the government'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    24656,
#    24692): ([('wm/concept/time/meher', 1.0),
#     None,
#     ('wm/process/farming/harvesting', 0.9268314838409424),
#     None], 'above average 2013-2014 Meher harvest'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    24779,
#    24826): ([('wm/concept/goods/agricultural', 1.0),
#     None,
#     ('wm/process/transmission', 0.5137871503829956),
#     None], 'marginal agricultural areas in Tigray and Amhara'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    25001,
#    25020): ([('wm/process/consumption', 0.5806748270988464),
#     None,
#     None,
#     None], 'mostly normal supply'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    25023,
#    25050): ([('wm/concept/goods/food', 1.0),
#     ('wm/property/price_or_cost', 1.0),
#     None,
#     None], 'prices of major staple foods'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    25072,
#    25083): ([('wm/concept/economy/commerce', 0.8099005222320557),
#     None,
#     None,
#     None], 'most markets'),
#   ('0a94f8c62f1291636f8a65840d914099',
#    25164,
#    25176): ([('wm/concept/environment/climate_change/higher_temperatures',
#      0.5411682724952698),
#     None,
#     ('wm/process/consumption', 0.464838445186615),
#     None], 'higher volume'),
#   ...}}

# %%
groundings_by_indexed_event = defaultdict(dict)
for part, indexed_evs in indexed_events.items():
    for index, grounding in indexed_evs.items():
        groundings_by_indexed_event[index][part] = grounding[0]
        groundings_by_indexed_event[index]['text'] = grounding[1]

# %%
dict(groundings_by_indexed_event)
# Out:
# {('0a6200447248b0bfb4a67d0fb5e84cbd',
#   344,
#   355): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/communication/informing', 0.876518726348877),
#    None], 'text': 'climate news', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/communication/informing', 0.44785910844802856),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/publication', 0.42294541001319885),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   433,
#   459): {'amyoutput': [('wm/process/communication/informing',
#     0.8533480167388916),
#    ('wm/property/stability', 1.0509308576583862),
#    None,
#    None], 'text': 'You may not have noticed it', 'winoutput1': [('wm/concept/frequency',
#     0.5604546070098877),
#    None,
#    ('wm/process/stay_or_remain', 0.5931714773178101),
#    None], 'winoutput2': [('wm/concept/time/timely', 0.5184054374694824),
#    None,
#    ('wm/process/communication/informing', 0.5429894328117371),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   522,
#   571): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/communication/meeting', 1.7538217306137085),
#    None], 'text': 'collapse of the COP25 climate conference in Madrid', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/communication/meeting', 0.815366268157959),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/communication/meeting', 0.815366268157959),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   566,
#   571): {'amyoutput': [('wm/concept/economy/tourism', 0.63947594165802),
#    None,
#    None,
#    None], 'text': 'Madrid', 'winoutput1': [('wm/concept/economy/tourism',
#     0.2879948019981384),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/economy/tourism', 0.27552205324172974),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   901,
#   934): {'amyoutput': [('wm/property/preparedness', 0.8710763454437256),
#    None,
#    None,
#    None], 'text': 'both the most optimistic scenarios', 'winoutput1': [('wm/process/prediction',
#     0.583583652973175),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/prediction', 0.5798161625862122),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   944,
#   964): {'amyoutput': [('wm/concept/perception', 0.884898841381073),
#    None,
#    None,
#    None], 'text': 'most pessimistic ones', 'winoutput1': [('wm/concept/perception',
#     0.5122776031494141),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/perception', 0.5459543466567993),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   1212,
#   1233): {'amyoutput': [('wm/property/stability', 0.8919515013694763),
#    None,
#    None,
#    None], 'text': 'both good and bad news', 'winoutput1': [('wm/concept/time/timely',
#     0.5783777832984924),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/humanitarian_assistance/food_aid',
#     0.5529233813285828),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   1387,
#   1395): {'amyoutput': [('wm/property/quality', 0.9921055436134338),
#    None,
#    None,
#    None], 'text': 'good news', 'winoutput1': [('wm/concept/infrastructure/communication',
#     0.5773861408233643),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/infrastructure/communication',
#     0.5989480018615723),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   1541,
#   1604): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/communication/campaign', 1.2903261184692383),
#    None], 'text': 'IEA is not known to be optimistic, at least to climate advocates', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/communication/campaign', 0.6724364757537842),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/communication/campaign', 0.7470046877861023),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   1818,
#   1843): {'amyoutput': [('wm/process/prediction', 1.0),
#    ('wm/property/widespread', 1.0096060037612915),
#    None,
#    None], 'text': 'most noteworthy prediction', 'winoutput1': [('wm/process/prediction',
#     1.0),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/prediction', 1.0), None, None, None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   1898,
#   1907): {'amyoutput': [('wm/concept/entity/hamas', 0.622750997543335),
#    ('wm/property/aftermath', 0.876968264579773),
#    None,
#    None], 'text': 'IEA report', 'winoutput1': [('wm/concept/entity/hamas',
#     0.27545109391212463),
#    None,
#    ('wm/process/communication/informing', 0.7289830446243286),
#    None], 'winoutput2': [('wm/concept/entity/hamas', 0.2296450287103653),
#    None,
#    ('wm/process/communication/informing', 0.7289830446243286),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   1916,
#   1943): {'amyoutput': [('wm/concept/environment/natural_resources/fossil_fuels',
#     1.6655217409133911),
#    ('wm/property/stability', 0.9848251938819885),
#    None,
#    None], 'text': 'only current carbon policies', 'winoutput1': [('wm/concept/innovation',
#     0.5437384843826294),
#    None,
#    ('wm/process/stay_or_remain', 0.5724933743476868),
#    None], 'winoutput2': [('wm/concept/government/legislation',
#     0.5190000534057617),
#    None,
#    ('wm/process/stay_or_remain', 0.5302284359931946),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   1952,
#   1983): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/research', 0.9967037439346313),
#    None], 'text': 'nearly everyone studying climate', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/research', 0.5379979014396667),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/research', 0.5894829630851746),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   2173,
#   2202): {'amyoutput': [('wm/property/price_or_cost', 1.0446996688842773),
#    None,
#    None,
#    None], 'text': 'less warming than is suggested', 'winoutput1': [('wm/process/consumption',
#     0.566226601600647),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/consumption', 0.5239616632461548),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   2285,
#   2303): {'amyoutput': [('wm/concept/entity/hamas', 0.5023889541625977),
#    None,
#    None,
#    None], 'text': '" "RCP8.5" scenario', 'winoutput1': [('wm/concept/entity/hamas',
#     0.20706488192081451),
#    None,
#    None,
#    None], 'winoutput2': None},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   2471,
#   2504): {'amyoutput': [('wm/property/preparedness', 0.9909564852714539),
#    None,
#    None,
#    None], 'text': 'their last major assessment report', 'winoutput1': [('wm/concept/time/late_onset',
#     0.5745933651924133),
#    None,
#    ('wm/process/research', 0.5052633285522461),
#    None], 'winoutput2': [('wm/concept/time/late_onset', 0.5804670453071594),
#    None,
#    ('wm/process/transportation/commercial_transportation', 0.4534319043159485),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   2577,
#   2600): {'amyoutput': [('wm/process/start', 0.7087772488594055),
#    ('wm/property/quality', 0.9116207361221313),
#    None,
#    None], 'text': 'highest arc of emissions', 'winoutput1': [('wm/concept/environment/emissions',
#     1.0),
#    None,
#    ('wm/process/assurance', 0.45329082012176514),
#    None], 'winoutput2': [('wm/concept/environment/emissions', 1.0),
#    None,
#    ('wm/process/hatching', 0.44084492325782776),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   3081,
#   3103): {'amyoutput': [('wm/process/farming/planting', 0.9372536540031433),
#    None,
#    None,
#    None], 'text': 'Those deep in the weeds', 'winoutput1': [('wm/process/farming/planting',
#     0.5465546250343323),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/time/dry_season', 0.5202277898788452),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   3310,
#   3344): {'amyoutput': [('wm/property/aftermath', 0.9644799828529358),
#    None,
#    None,
#    None], 'text': 'deep - and perhaps fatal - problems', 'winoutput1': [('wm/concept/health/case_volume',
#     0.5642983317375183),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/health/case_volume', 0.5745465755462646),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd', 3315, 3315): {'amyoutput': None,
#   'text': '-',
#   'winoutput1': None,
#   'winoutput2': None},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   3487,
#   3502): {'amyoutput': [('wm/property/volatility', 0.9331188201904297),
#    None,
#    None,
#    None], 'text': 'usual" scenarios', 'winoutput1': [('wm/concept/intervention',
#     0.5412912368774414),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/intervention', 0.5528866052627563),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   3908,
#   3927): {'amyoutput': [('wm/property/stability', 1.0292072296142578),
#    None,
#    None,
#    None], 'text': 'that global coal use', 'winoutput1': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6073142290115356),
#    ('wm/property/geographic_resolution/global', 1.0),
#    ('wm/process/communication/informing', 0.6425358057022095),
#    None], 'winoutput2': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6131879091262817),
#    ('wm/property/geographic_resolution/global', 1.0),
#    ('wm/process/prevention', 0.6351994276046753),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   4206,
#   4233): {'amyoutput': [('wm/property/stability', 1.0663681030273438),
#    None,
#    None,
#    None], 'text': 'perhaps even dramatic growth', 'winoutput1': [('wm/process/access',
#     0.5466161966323853),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/stay_or_remain', 0.5262982249259949),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   4344,
#   4386): {'amyoutput': [('wm/concept/plan', 1.5115242004394531),
#    ('wm/property/stability', 1.0509308576583862),
#    None,
#    None], 'text': "given how much we don't know about the path", 'winoutput1': [('wm/concept/entity/people',
#     0.567862331867218),
#    None,
#    ('wm/process/provision', 0.5866323113441467),
#    None], 'winoutput2': [('wm/concept/entity/people', 0.4487359821796417),
#    None,
#    ('wm/process/provision', 0.6389783024787903),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   4479,
#   4511): {'amyoutput': [('wm/process/flow', 0.7172248959541321),
#    ('wm/property/aftermath', 1.0198456048965454),
#    None,
#    None], 'text': 'recent drops in renewable pricing', 'winoutput1': [('wm/concept/health/case_volume',
#     0.5334577560424805),
#    None,
#    ('wm/process/flow', 0.3463065028190613),
#    None], 'winoutput2': [('wm/concept/health/case_volume', 0.5147742033004761),
#    None,
#    ('wm/process/flow', 0.321929007768631),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   4495,
#   4511): {'amyoutput': [('wm/property/price_or_cost', 1.008305311203003),
#    None,
#    None,
#    None], 'text': 'renewable pricing', 'winoutput1': [('wm/concept/energy',
#     0.6317105293273926),
#    None,
#    ('wm/process/transaction', 0.5109022855758667),
#    None], 'winoutput2': [('wm/concept/energy', 0.6301804184913635),
#    None,
#    ('wm/process/transaction', 0.522239089012146),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   4522,
#   4575): {'amyoutput': [('wm/process/detection', 1.659497618675232),
#    ('wm/property/geographic_resolution/global', 1.9016761779785156),
#    None,
#    None], 'text': 'positive signs for coal decline in the developed world', 'winoutput1': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6073142290115356),
#    None,
#    ('wm/process/reaction_or_response', 0.4835773706436157),
#    None], 'winoutput2': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6131879091262817),
#    None,
#    ('wm/process/research', 0.4784700572490692),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   4541,
#   4575): {'amyoutput': [('wm/property/geographic_resolution/global',
#     1.9016761779785156),
#    None,
#    None,
#    None], 'text': 'coal decline in the developed world', 'winoutput1': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6073142290115356),
#    None,
#    ('wm/process/population/death', 0.5101418495178223),
#    None], 'winoutput2': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6131879091262817),
#    None,
#    ('wm/process/population/death', 0.5143426060676575),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   4561,
#   4575): {'amyoutput': [('wm/property/geographic_resolution/global',
#     1.0854711532592773),
#    None,
#    None,
#    None], 'text': 'developed world', 'winoutput1': [('wm/concept/innovation',
#     0.5978859663009644),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/innovation', 0.5928146839141846),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   4791,
#   4866): {'amyoutput': [('wm/concept/energy', 1.0),
#    None,
#    ('wm/process/communication/description', 0.7926035523414612),
#    None], 'text': 'energy use, which is not at all the whole picture when it comes to emissions', 'winoutput1': [('wm/concept/energy',
#     1.0),
#    None,
#    ('wm/process/consumption', 0.7309308648109436),
#    None], 'winoutput2': [('wm/concept/energy', 1.0),
#    None,
#    ('wm/process/consumption', 0.7309308648109436),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   5044,
#   5087): {'amyoutput': [('wm/process/prediction', 1.2336145639419556),
#    ('wm/property/price_or_cost', 1.031987190246582),
#    None,
#    None], 'text': 'coal use fails to grow at the predicted rate', 'winoutput1': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6073142290115356),
#    None,
#    ('wm/process/consumption', 0.7309308648109436),
#    None], 'winoutput2': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6131879091262817),
#    None,
#    ('wm/process/consumption', 0.7309308648109436),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   5124,
#   5138): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    ('wm/property/preparedness', 0.8960893154144287),
#    None,
#    None], 'text': 'climate impacts', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/mitigation', 0.5665561556816101),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/mitigation', 0.5441927313804626),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   5390,
#   5408): {'amyoutput': [('wm/property/diversity', 0.9957168698310852),
#    None,
#    None,
#    None], 'text': 'large uncertainties', 'winoutput1': [('wm/process/destocking',
#     0.5108051300048828),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/combining', 0.5032892823219299),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   5476,
#   5502): {'amyoutput': [('wm/process/communication/highlighting',
#     0.7707635760307312),
#    None,
#    None,
#    None], 'text': 'remarkably insightful paper', 'winoutput1': [('wm/concept/information/intelligence_information',
#     0.3931213319301605),
#    None,
#    ('wm/process/communication/highlighting', 0.4216870069503784),
#    None], 'winoutput2': [('wm/concept/information/intelligence_information',
#     0.3799230456352234),
#    None,
#    ('wm/process/stay_or_remain', 0.40925201773643494),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   5476,
#   5670): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/publication', 1.1587711572647095),
#    None], 'text': 'remarkably insightful paper published by the Breakthrough Institute on Wednesday - "in a right and just world, this would be the most high-impact piece of climate writing of the month of December', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/access', 0.6543319225311279),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/publication', 0.706143856048584),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   5814,
#   5842): {'amyoutput': [('wm/concept/cultural_norms', 0.8997845649719238),
#    None,
#    None,
#    None], 'text': 'very conservative assumptions', 'winoutput1': [('wm/concept/cultural_norms',
#     0.5443995594978333),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/economy/economy', 0.5785489082336426),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   6149,
#   6208): {'amyoutput': [('wm/concept/energy', 1.0),
#    None,
#    ('wm/process/modification', 0.73780357837677),
#    None], 'text': 'transitions in the global energy system over the past decade', 'winoutput1': [('wm/concept/energy',
#     1.0),
#    None,
#    ('wm/process/training/agriculture_extension', 0.5732402801513672),
#    None], 'winoutput2': [('wm/concept/energy', 1.0),
#    None,
#    ('wm/process/training/agriculture_extension', 0.5766121745109558),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   6222,
#   6312): {'amyoutput': [('wm/concept/trend', 1.0),
#    None,
#    ('wm/process/prediction', 1.5695524215698242),
#    None], 'text': 'conservative business-as-usual projection of current trends in the energy system continuing', 'winoutput1': [('wm/concept/trend',
#     1.0),
#    None,
#    ('wm/process/prediction', 0.6771643757820129),
#    None], 'winoutput2': [('wm/concept/trend', 1.0),
#    None,
#    ('wm/process/prediction', 0.6771643757820129),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   6339,
#   6366): {'amyoutput': [('wm/concept/time', 0.7698357701301575),
#    ('wm/property/geographic_resolution/global', 0.8593756556510925),
#    None,
#    None], 'text': 'warming of around 3C by 2100', 'winoutput1': [('wm/concept/time',
#     0.3391241431236267),
#    None,
#    ('wm/process/mitigation', 0.4320427179336548),
#    None], 'winoutput2': [('wm/concept/entity/people/newsmedia',
#     0.265406996011734),
#    None,
#    ('wm/process/intake', 0.4278191924095154),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd', 6404, 6459): {'amyoutput': None,
#   'text': 'higher-emissions world than the IEA projects is possible',
#   'winoutput1': [('wm/process/construction', 0.553880512714386),
#    None,
#    None,
#    None],
#   'winoutput2': [('wm/process/development', 0.5354362726211548),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   6665,
#   6681): {'amyoutput': [('wm/property/preparedness', 1.0092500448226929),
#    None,
#    None,
#    None], 'text': 'absence of policy', 'winoutput1': [('wm/concept/policy_making',
#     0.6924005746841431),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/policy_making', 0.7213506102561951),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   6693,
#   6729): {'amyoutput': [('wm/property/price_or_cost', 1.031987190246582),
#    None,
#    None,
#    None], 'text': 'rate of emissions reductions required', 'winoutput1': [('wm/concept/environment/emissions',
#     1.0),
#    None,
#    ('wm/process/inflation', 0.5008825063705444),
#    None], 'winoutput2': [('wm/concept/environment/emissions', 1.0),
#    None,
#    ('wm/process/inflation', 0.47525447607040405),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   7186,
#   7287): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    ('wm/property/stability', 1.0663681030273438),
#    None,
#    None], 'text': 'that they did not see RCP8.5 as a plausible scenario, even in the absence of meaningful climate policy', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/access', 0.614555299282074),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/prevention', 0.6077515482902527),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   7240,
#   7287): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    ('wm/property/stability', 1.0663681030273438),
#    None,
#    None], 'text': 'even in the absence of meaningful climate policy', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/access', 0.614555299282074),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/prevention', 0.6077515482902527),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   7521,
#   7540): {'amyoutput': [('wm/property/common_understanding',
#     0.8730589747428894),
#    None,
#    None,
#    None], 'text': "That's the good news", 'winoutput1': [('wm/concept/time/timely',
#     0.5540769100189209),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/infrastructure/communication',
#     0.5493886470794678),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   7547,
#   7585): {'amyoutput': [('wm/property/right_to_use', 0.9495186805725098),
#    None,
#    None,
#    None], 'text': 'it is not, in the end, simple good news', 'winoutput1': [('wm/concept/time/timely',
#     0.6407685875892639),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/time/timely', 0.6417247653007507),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   7616,
#   7676): {'amyoutput': [('wm/process/extraction', 0.8149733543395996),
#    None,
#    None,
#    None], 'text': 'corresponding good news in all the other sectors of emissions', 'winoutput1': [('wm/concept/environment/emissions',
#     1.0),
#    None,
#    ('wm/process/extraction', 0.4598334729671478),
#    None], 'winoutput2': [('wm/concept/environment/emissions', 1.0),
#    None,
#    ('wm/process/extraction', 0.46105825901031494),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   8068,
#   8073): {'amyoutput': [('wm/concept/humanitarian_assistance/non_food_items',
#     1.199434757232666),
#    None,
#    None,
#    None], 'text': 'bucket', 'winoutput1': [('wm/concept/humanitarian_assistance/non_food_items',
#     0.6042680144309998),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/humanitarian_assistance/non_food_items',
#     0.6708996891975403),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd', 8203, 8221): {'amyoutput': None,
#   'text': 'negative emissions)',
#   'winoutput1': [('wm/concept/trend', 0.5219626426696777),
#    None,
#    ('wm/process/consumption', 0.45816051959991455),
#    None],
#   'winoutput2': [('wm/concept/trend', 0.5241124033927917),
#    None,
#    ('wm/process/mitigation', 0.45523977279663086),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   8573,
#   8611): {'amyoutput': [('wm/concept/innovation', 1.018442988395691),
#    None,
#    None,
#    None], 'text': 'next generation of more advanced models', 'winoutput1': [('wm/concept/innovation',
#     0.648417592048645),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/innovation', 0.6532102227210999),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   8573,
#   8734): {'amyoutput': [('wm/concept/environment/meteorology/temperature',
#     1.0),
#    None,
#    ('wm/process/breeding', 1.4562797546386719),
#    None], 'text': 'next generation of more advanced models are currently being developed to better predict what amount of temperature rise would result from certain emissions levels', 'winoutput1': [('wm/concept/environment/meteorology/temperature',
#     1.0),
#    None,
#    ('wm/process/prediction', 0.85971599817276),
#    None], 'winoutput2': [('wm/concept/environment/meteorology/temperature',
#     1.0),
#    None,
#    ('wm/process/prediction', 0.85971599817276),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   8666,
#   8691): {'amyoutput': [('wm/concept/environment/meteorology/temperature',
#     1.0),
#    ('wm/property/price_or_cost', 1.0690785646438599),
#    None,
#    None], 'text': 'amount of temperature rise', 'winoutput1': [('wm/concept/environment/meteorology/temperature',
#     1.0),
#    None,
#    ('wm/process/destocking', 0.5289142727851868),
#    None], 'winoutput2': [('wm/concept/environment/meteorology/temperature',
#     1.0),
#    None,
#    ('wm/process/transaction', 0.5219336152076721),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   8741,
#   8791): {'amyoutput': [('wm/concept/entity/people', 0.8576390147209167),
#    ('wm/property/stability', 0.9717144966125488),
#    ('wm/process/training/training', 0.8344540596008301),
#    None], 'text': 'while the models are by no means speaking in unison', 'winoutput1': [('wm/concept/entity/people',
#     0.48684364557266235),
#    None,
#    ('wm/process/research', 0.38850635290145874),
#    None], 'winoutput2': [('wm/concept/entity/people/academic',
#     0.4765016436576843),
#    None,
#    ('wm/process/training/training', 0.44703295826911926),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   8796,
#   8825): {'amyoutput': [('wm/property/shortage', 0.9299516677856445),
#    None,
#    None,
#    None], 'text': 'concerning proportion of those', 'winoutput1': [('wm/process/research',
#     0.5393263101577759),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/research', 0.5331427454948425),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   8865,
#   8871): {'amyoutput': [('wm/property/geographic_resolution/global',
#     0.9184470772743225),
#    None,
#    None,
#    None], 'text': 'climate', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   8913,
#   8921): {'amyoutput': [('wm/property/efficiency_or_efficacy',
#     0.8898687958717346),
#    None,
#    None,
#    None], 'text': 'emissions', 'winoutput1': [('wm/concept/environment/emissions',
#     1.0),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/environment/emissions', 1.0),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   8988,
#   8999): {'amyoutput': [('wm/property/stability', 1.027764081954956),
#    None,
#    None,
#    None], 'text': 'better place', 'winoutput1': [('wm/concept/time/timely',
#     0.573278546333313),
#    None,
#    ('wm/process/access', 0.5815207958221436),
#    None], 'winoutput2': [('wm/concept/plan', 0.5649003982543945),
#    None,
#    ('wm/process/access', 0.5336382389068604),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   9119,
#   9134): {'amyoutput': [('wm/property/price_or_cost', 1.0099023580551147),
#    None,
#    None,
#    None], 'text': 'higher emissions', 'winoutput1': [('wm/concept/environment/emissions',
#     0.6633702516555786),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/environment/emissions',
#     0.7550641894340515),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   9141,
#   9178): {'amyoutput': [('wm/property/stability', 0.9803890585899353),
#    None,
#    None,
#    None], 'text': 'perhaps, in theory, even a worse place', 'winoutput1': [('wm/concept/frequency',
#     0.6021735072135925),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/frequency', 0.5903081893920898),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd', 9271, 9292): {'amyoutput': None,
#   'text': 'our high-end estimates',
#   'winoutput1': [('wm/process/prediction', 0.5632777214050293),
#    None,
#    None,
#    None],
#   'winoutput2': [('wm/process/prediction', 0.5784143209457397),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   9386,
#   9497): {'amyoutput': [('wm/concept/economy/budget', 1.0),
#    None,
#    ('wm/process/observation', 0.8894603252410889),
#    None], 'text': 'As this animation usefully shows, we are practically already at the limit of our "carbon budget" for 1.5 degrees', 'winoutput1': [('wm/concept/economy/budget',
#     1.0),
#    None,
#    ('wm/process/stalling', 0.7501938343048096),
#    None], 'winoutput2': [('wm/concept/economy/budget', 1.0),
#    None,
#    ('wm/process/stalling', 0.7501938343048096),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd', 9487, 9505): {'amyoutput': None,
#   'text': '1.5 degrees Celsius',
#   'winoutput1': None,
#   'winoutput2': None},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   9749,
#   9792): {'amyoutput': [('wm/concept/environment/natural_resources/fossil_fuels',
#     1.6655217409133911),
#    None,
#    ('wm/process/flow', 0.7579807639122009),
#    ('wm/property/stability',
#     1.027018666267395)], 'text': 'never again emitting another ounce of carbon', 'winoutput1': [('wm/concept/time/timely',
#     0.558491587638855),
#    None,
#    ('wm/process/attempt', 0.5775232315063477),
#    None], 'winoutput2': [('wm/concept/health/life', 0.5340671539306641),
#    None,
#    ('wm/process/attempt', 0.6067171692848206),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd', 9970, 9989): {'amyoutput': None,
#   'text': 'not just 1.5 degrees',
#   'winoutput1': [('wm/concept/time/timely', 0.5981644988059998),
#    None,
#    ('wm/process/access', 0.6017577052116394),
#    None],
#   'winoutput2': [('wm/concept/time/timely', 0.5800438523292542),
#    None,
#    ('wm/process/access', 0.5538751482963562),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   10206,
#   10307): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/communication/ask/question', 1.1444419622421265),
#    None], 'text': 'This may all seem dizzyingly complicated on-the-one-hand-and-on-the-other inside baseball climate talk', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/stay_or_remain', 0.6430463194847107),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/communication/ask/question', 0.6259524822235107),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   10287,
#   10307): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/communication/ask/question', 1.1444419622421265),
#    None], 'text': 'baseball climate talk', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/communication/ask/question', 0.6200788021087646),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/communication/ask/question', 0.6259524822235107),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   10314,
#   10331): {'amyoutput': [('wm/concept/economy/commercial_farmers',
#     0.798058807849884),
#    None,
#    None,
#    None], 'text': 'four big takeaways', 'winoutput1': [('wm/concept/economy/commercial_farmers',
#     0.4513942003250122),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/economy/marketplace',
#     0.4478432238101959),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   10547,
#   10566): {'amyoutput': [('wm/property/geographic_resolution/global',
#     0.857661783695221),
#    None,
#    None,
#    None], 'text': 'challenge of warming', 'winoutput1': [('wm/concept/environment/climate_change',
#     0.6003803610801697),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/environment/climate_change',
#     0.654540479183197),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   11253,
#   11287): {'amyoutput': [('wm/process/hatching', 0.7256255149841309),
#    ('wm/property/geographic_resolution/national', 0.9240543246269226),
#    None,
#    None], 'text': 'major determinant of warming levels', 'winoutput1': [('wm/concept/environment/climate_change',
#     0.6646497249603271),
#    None,
#    ('wm/process/research', 0.5052633285522461),
#    None], 'winoutput2': [('wm/concept/environment/climate_change',
#     0.7047863006591797),
#    None,
#    ('wm/process/transportation/commercial_transportation', 0.4534319043159485),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   11347,
#   11397): {'amyoutput': [('wm/concept/environment/natural_resources/fossil_fuels',
#     1.6655217409133911),
#    ('wm/property/price_or_cost', 1.0690785646438599),
#    ('wm/process/consumption', 0.5565191507339478),
#    ('wm/property/stability',
#     1.0292072296142578)], 'text': 'that putting X amount of carbon into the atmosphere', 'winoutput1': [('wm/concept/frequency',
#     0.6101388931274414),
#    None,
#    ('wm/process/attempt', 0.5254901647567749),
#    None], 'winoutput2': [('wm/concept/plan', 0.5713638067245483),
#    None,
#    ('wm/process/attempt', 0.5156267285346985),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   11412,
#   11458): {'amyoutput': [('wm/concept/entity/locations/urban_area',
#     0.8551421165466309),
#    None,
#    ('wm/process/communication/ask', 0.7620482444763184),
#    None], 'text': 'Y amount of warming on a timescale of a century', 'winoutput1': [('wm/concept/entity/people/elites',
#     0.45323532819747925),
#    None,
#    ('wm/process/communication/ask', 0.276228129863739),
#    None], 'winoutput2': [('wm/concept/entity/locations/urban_area',
#     0.46108120679855347),
#    None,
#    ('wm/process/communication/informing', 0.20672830939292908),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   11559,
#   11595): {'amyoutput': [('wm/concept/goods/minerals', 0.8200423717498779),
#    None,
#    ('wm/process/training/agriculture_extension', 0.7622754573822021),
#    None], 'text': "Whether China's coal use grows slowly", 'winoutput1': [('wm/concept/goods/minerals',
#     0.4055018424987793),
#    None,
#    ('wm/process/consumption', 0.7309308648109436),
#    None], 'winoutput2': [('wm/concept/goods/minerals', 0.40073689818382263),
#    None,
#    ('wm/process/consumption', 0.7309308648109436),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   11598,
#   11758): {'amyoutput': [('wm/concept/time/late_onset', 0.8694588541984558),
#    None,
#    ('wm/process/farming/herding', 0.6756770610809326),
#    None], 'text': 'plateaus and then drops slowly, or drops precipitously over the next two decades - that is not something it is even possible to know, really, though we can guess', 'winoutput1': [('wm/concept/time/timely',
#     0.5895014405250549),
#    None,
#    ('wm/process/farming/herding', 0.33703097701072693),
#    None], 'winoutput2': [('wm/concept/time/timely', 0.5770286917686462),
#    None,
#    ('wm/process/farming/herding', 0.31466755270957947),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   12288,
#   12315): {'amyoutput': [('wm/process/depreciation', 0.5958523154258728),
#    ('wm/property/price_or_cost', 1.0298583507537842),
#    None,
#    None], 'text': 'sixfold increase in coal use', 'winoutput1': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6073142290115356),
#    None,
#    ('wm/process/depreciation', 0.2997393310070038),
#    None], 'winoutput2': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6131879091262817),
#    None,
#    ('wm/process/population/migrate/emigrate', 0.23497280478477478),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   12308,
#   12315): {'amyoutput': [('wm/property/usefulness', 0.9923022985458374),
#    None,
#    None,
#    None], 'text': 'coal use', 'winoutput1': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6073142290115356),
#    None,
#    ('wm/process/consumption', 0.7309308648109436),
#    None], 'winoutput2': [('wm/concept/environment/natural_resources/fossil_fuels',
#     0.6131879091262817),
#    None,
#    ('wm/process/consumption', 0.7309308648109436),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   12678,
#   12685): {'amyoutput': [('wm/property/stability', 0.9373384714126587),
#    None,
#    None,
#    None], 'text': 'no point', 'winoutput1': [('wm/process/access',
#     0.5551865100860596),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/research', 0.5200624465942383),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   12829,
#   12863): {'amyoutput': [('wm/process/farming/irrigation', 0.771620512008667),
#    ('wm/property/stability', 0.9617336988449097),
#    None,
#    None], 'text': 'more of the powerful greenhouse gas', 'winoutput1': [('wm/concept/entity/people',
#     0.541533350944519),
#    None,
#    ('wm/process/manipulation', 0.47500085830688477),
#    None], 'winoutput2': [('wm/concept/time/timely', 0.49151915311813354),
#    None,
#    ('wm/process/enabling', 0.4884105920791626),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   12829,
#   12920): {'amyoutput': [('wm/concept/entity/locations/country', 1.0),
#    None,
#    ('wm/process/consumption', 0.8641990423202515),
#    None], 'text': 'more of the powerful greenhouse gas than the entire oil and gas industries of many countries', 'winoutput1': [('wm/concept/entity/locations/country',
#     1.0),
#    None,
#    ('wm/process/stay_or_remain', 0.5360856652259827),
#    None], 'winoutput2': [('wm/concept/entity/locations/country', 1.0),
#    None,
#    ('wm/process/communication/informing', 0.5317150950431824),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13085,
#   13128): {'amyoutput': [('wm/property/common_understanding',
#     1.1443686485290527),
#    None,
#    None,
#    None], 'text': 'their understanding on what level of warming', 'winoutput1': [('wm/concept/environment/climate_change',
#     0.6646497249603271),
#    None,
#    ('wm/process/research', 0.5960618853569031),
#    None], 'winoutput2': [('wm/concept/environment/climate_change',
#     0.7047863006591797),
#    None,
#    ('wm/process/research', 0.5801792144775391),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13108,
#   13128): {'amyoutput': [('wm/property/stability', 0.9733248949050903),
#    None,
#    None,
#    None], 'text': 'what level of warming', 'winoutput1': [('wm/concept/environment/climate_change',
#     0.6646497249603271),
#    None,
#    ('wm/process/communication/informing', 0.6651880741119385),
#    None], 'winoutput2': [('wm/concept/environment/climate_change',
#     0.7047863006591797),
#    None,
#    ('wm/process/communication/informing', 0.6229231357574463),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13113,
#   13128): {'amyoutput': [('wm/property/stability', 0.8887057900428772),
#    None,
#    None,
#    None], 'text': 'level of warming', 'winoutput1': [('wm/concept/environment/climate_change',
#     0.6646497249603271),
#    None,
#    ('wm/process/training/training', 0.5176863074302673),
#    None], 'winoutput2': [('wm/concept/environment/climate_change',
#     0.7047863006591797),
#    None,
#    ('wm/process/development', 0.5190311670303345),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13224,
#   13246): {'amyoutput': [('wm/concept/information/misinformation',
#     0.8439232110977173),
#    ('wm/property/price_or_cost', 1.0446996688842773),
#    ('wm/process/access', 0.8590467572212219),
#    None], 'text': 'less alarmist direction', 'winoutput1': [('wm/concept/information/misinformation',
#     0.4705753028392792),
#    None,
#    ('wm/process/consumption', 0.566226601600647),
#    None], 'winoutput2': [('wm/concept/information/misinformation',
#     0.45605841279029846),
#    None,
#    ('wm/process/consumption', 0.5239616632461548),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13249,
#   13258): {'amyoutput': [('wm/concept/entity/people/adviser',
#     1.5973329544067383),
#    None,
#    None,
#    None], 'text': 'Scientists', 'winoutput1': [('wm/concept/entity/people/adviser',
#     0.6979997754096985),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/entity/people/adviser',
#     0.6979997754096985),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13317,
#   13328): {'amyoutput': [('wm/concept/entity/hamas', 0.5023889541625977),
#    ('wm/property/usefulness', 0.8701587319374084),
#    None,
#    None], 'text': 'using RCP8.5', 'winoutput1': [('wm/concept/entity/hamas',
#     0.20706488192081451),
#    None,
#    ('wm/process/combining', 0.5455790758132935),
#    None], 'winoutput2': [('wm/process/combining', 0.5408141613006592),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd', 13349, 13358): {'amyoutput': None,
#   'text': 'no policy"',
#   'winoutput1': [('wm/process/legislation/regulation', 0.5515075922012329),
#    None,
#    None,
#    None],
#   'winoutput2': [('wm/process/conflict/peacebuilding', 0.5594736933708191),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13376,
#   13402): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    ('wm/property/aftermath', 0.858471691608429),
#    None,
#    None], 'text': 'usual" climate trajectories', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/stalling', 0.45242947340011597),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/stalling', 0.4476645290851593),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13424,
#   13442): {'amyoutput': [('wm/property/common_understanding',
#     0.8993669152259827),
#    None,
#    None,
#    None], 'text': 'describing research', 'winoutput1': [('wm/process/research',
#     0.7000733613967896),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/research', 0.7335985898971558),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13435,
#   13442): {'amyoutput': [('wm/property/common_understanding',
#     0.88165283203125),
#    None,
#    None,
#    None], 'text': 'research', 'winoutput1': [('wm/process/research', 1.0),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/research', 1.0), None, None, None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13489,
#   13500): {'amyoutput': [('wm/property/geographic_resolution/global',
#     1.0802714824676514),
#    None,
#    None,
#    None], 'text': 'usual" world', 'winoutput1': [('wm/concept/time/timely',
#     0.5756477117538452),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/time/timely', 0.5656367540359497),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13796,
#   13820): {'amyoutput': [('wm/property/volatility', 1.7396910190582275),
#    None,
#    None,
#    None], 'text': 'face of great uncertainty', 'winoutput1': [('wm/concept/crisis_or_disaster/conflict/tension',
#     0.5926936864852905),
#    None,
#    ('wm/process/disguise', 0.4723641276359558),
#    None], 'winoutput2': [('wm/concept/crisis_or_disaster/conflict/tension',
#     0.6214666366577148),
#    None,
#    ('wm/process/disguise', 0.46759918332099915),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   13967,
#   13991): {'amyoutput': [('wm/property/stability', 0.9206315875053406),
#    None,
#    None,
#    None], 'text': 'positive or happy outcome', 'winoutput1': [('wm/concept/time/timely',
#     0.5488051176071167),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/time/timely', 0.5620830655097961),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   14134,
#   14147): {'amyoutput': [('wm/concept/population_demographics/population_density/de-population',
#     0.7967486381530762),
#    None,
#    None,
#    None], 'text': 'sea-level rise', 'winoutput1': [('wm/concept/population_demographics/population_density/de-population',
#     0.4504115581512451),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/population_demographics/population_density/de-population',
#     0.4482651650905609),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   14234,
#   14249): {'amyoutput': [('wm/property/widespread', 1.0618946552276611),
#    None,
#    None,
#    None], 'text': 'many millions of', 'winoutput1': [('wm/process/stay_or_remain',
#     0.5360856652259827),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/communication/informing',
#     0.5317150950431824),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   14598,
#   14603): {'amyoutput': [('wm/property/drug_resistance', 0.8678146600723267),
#    None,
#    None,
#    None], 'text': 'strain', 'winoutput1': [('wm/process/mitigation',
#     0.45036929845809937),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/medical/quarantine',
#     0.47083422541618347),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   14810,
#   14844): {'amyoutput': [('wm/property/right_to_use', 0.8942840099334717),
#    None,
#    None,
#    None], 'text': 'that these "ndings do not, actually', 'winoutput1': [('wm/process/communication/informing',
#     0.5863070487976074),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/communication/informing',
#     0.5606790781021118),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   15026,
#   15066): {'amyoutput': [('wm/property/preparedness', 0.8769559264183044),
#    None,
#    None,
#    None], 'text': 'not from some projected scenario backward', 'winoutput1': [('wm/process/prediction',
#     0.6660398244857788),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/prediction', 0.7035759687423706),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   15454,
#   15458): {'amyoutput': [('wm/property/geographic_resolution/global',
#     1.9016761779785156),
#    None,
#    None,
#    None], 'text': 'world', 'winoutput1': [('wm/property/geographic_resolution/global',
#     0.9262571930885315),
#    None,
#    None,
#    None], 'winoutput2': [('wm/property/geographic_resolution/global',
#     0.9262571930885315),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   15512,
#   15520): {'amyoutput': [('wm/property/efficiency_or_efficacy',
#     0.8898687958717346),
#    None,
#    None,
#    None], 'text': 'emissions', 'winoutput1': [('wm/process/consumption',
#     0.45816051959991455),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/mitigation', 0.45523977279663086),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   15654,
#   15753): {'amyoutput': [('wm/concept/environment/climate',
#     0.9361006021499634),
#    None,
#    None,
#    None], 'text': 'emissions by 7.6 percent per year every year for the next decade, globally, to hit the Paris targets', 'winoutput1': [('wm/concept/environment/emissions',
#     1.0),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/environment/emissions', 1.0),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   15741,
#   15753): {'amyoutput': [('wm/concept/economy/tourism', 0.9084384441375732),
#    ('wm/property/preparedness', 0.8729010820388794),
#    None,
#    None], 'text': 'Paris targets', 'winoutput1': [('wm/concept/economy/tourism',
#     0.3860207796096802),
#    None,
#    ('wm/process/conflict/attack', 0.48130905628204346),
#    None], 'winoutput2': [('wm/concept/economy/tourism', 0.43836677074432373),
#    None,
#    ('wm/process/conflict/attack', 0.46318838000297546),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   15863,
#   15922): {'amyoutput': [('wm/concept/entity/locations/country', 1.0),
#    None,
#    ('wm/process/population', 1.1113851070404053),
#    None], 'text': 'many countries with populations collectively in the billions', 'winoutput1': [('wm/concept/entity/african_governments',
#     0.7051571011543274),
#    None,
#    ('wm/process/population', 1.0),
#    None], 'winoutput2': [('wm/concept/entity/african_governments',
#     0.7593172192573547),
#    None,
#    ('wm/process/population', 1.0),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd', 16124, 16154): {'amyoutput': None,
#   'text': 'perhaps the most signi"cant one',
#   'winoutput1': [('wm/process/access', 0.5466161966323853), None, None, None],
#   'winoutput2': [('wm/process/stay_or_remain', 0.5262982249259949),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   16161,
#   16220): {'amyoutput': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/start', 0.9266386032104492),
#    None], 'text': 'even in a year of dramatic political mobilization on climate', 'winoutput1': [('wm/concept/environment/climate',
#     1.0),
#    None,
#    ('wm/process/access', 0.614555299282074),
#    None], 'winoutput2': [('wm/concept/environment/climate', 1.0),
#    None,
#    ('wm/process/prevention', 0.6077515482902527),
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   16291,
#   16308): {'amyoutput': [('wm/property/stability', 1.036007285118103),
#    None,
#    None,
#    None], 'text': 'one major response', 'winoutput1': [('wm/process/access',
#     0.5849212408065796),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/access', 0.5370386838912964),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   17814,
#   17814): {'amyoutput': [('wm/process/communication/ask', 0.8085198402404785),
#    None,
#    None,
#    None], 'text': 'o', 'winoutput1': [('wm/process/training/agriculture_extension',
#     0.31174349784851074),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/modification', 0.25499045848846436),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   17821,
#   17827): {'amyoutput': [('wm/process/sharing', 0.7062708139419556),
#    None,
#    None,
#    None], 'text': 'smiling', 'winoutput1': [('wm/process/communication/ask',
#     0.3457612693309784),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/sharing', 0.35826539993286133),
#    None,
#    None,
#    None]},
#  ('0a6200447248b0bfb4a67d0fb5e84cbd',
#   18064,
#   18257): {'amyoutput': [('wm/concept/population_demographics/religion',
#     0.90233314037323),
#    ('wm/property/stability', 0.9169420003890991),
#    None,
# ...
#     0.5450250506401062),
#    None,
#    ('wm/process/start', 0.49218422174453735),
#    None], 'winoutput2': [('wm/concept/environment/natural_resources/land/pasture',
#     0.5601335763931274),
#    None,
#    ('wm/process/start', 0.5137460827827454),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   21706,
#   21796): {'amyoutput': [('wm/concept/entity/hamas', 0.6086655855178833),
#    None,
#    ('wm/process/securing', 0.9189330339431763),
#    ('wm/property/diversity',
#     1.0070642232894897)], 'text': 'other hand, planted area is only a little bit over 60 percent of average in parts of Tigray', 'winoutput1': [('wm/concept/entity/locations/urban_area',
#     0.5608078837394714),
#    None,
#    ('wm/process/access', 0.5509104132652283),
#    None], 'winoutput2': [('wm/concept/entity/locations/urban_area',
#     0.5559109449386597),
#    None,
#    ('wm/process/research', 0.535732090473175),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   21862,
#   21873): {'amyoutput': [('wm/property/fallow', 0.8903079628944397),
#    None,
#    None,
#    None], 'text': 'planted area', 'winoutput1': [('wm/concept/entity/locations/urban_area',
#     0.5608078837394714),
#    None,
#    ('wm/process/farming/planting', 0.8879470825195312),
#    None], 'winoutput2': [('wm/concept/entity/locations/urban_area',
#     0.5559109449386597),
#    None,
#    ('wm/process/farming/planting', 0.8879470825195312),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   21929,
#   21936): {'amyoutput': [('wm/property/preparedness', 0.9654415845870972),
#    None,
#    None,
#    None], 'text': 'planting', 'winoutput1': [('wm/process/farming/planting',
#     1.0),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/farming/planting', 1.0),
#    None,
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   22077,
#   22154): {'amyoutput': [('wm/concept/environment/meteorology/precipitation',
#     1.416393756866455),
#    None,
#    ('wm/process/start', 1.0),
#    None], 'text': 'delay of the start of the rains in these areas or somewhat erratic performance', 'winoutput1': [('wm/concept/environment/meteorology/precipitation',
#     0.7669873237609863),
#    None,
#    ('wm/process/start', 1.0),
#    None], 'winoutput2': [('wm/concept/environment/meteorology/precipitation',
#     0.8193332552909851),
#    None,
#    ('wm/process/start', 1.0),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   22177,
#   22196): {'amyoutput': [('wm/property/fallow', 0.8903079628944397),
#    None,
#    None,
#    None], 'text': 'average planted area', 'winoutput1': [('wm/concept/entity/locations/urban_area',
#     0.5608078837394714),
#    None,
#    ('wm/process/population', 0.49181199073791504),
#    None], 'winoutput2': [('wm/concept/entity/locations/urban_area',
#     0.5559109449386597),
#    None,
#    ('wm/process/prediction', 0.41342437267303467),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   22342,
#   22384): {'amyoutput': [('wm/concept/time/meher', 1.0),
#    None,
#    ('wm/process/preparation', 1.0),
#    None], 'text': 'Land preparation for long-cycle Meher crops', 'winoutput1': [('wm/concept/environment/natural_resources/land',
#     1.0),
#    None,
#    ('wm/process/preparation', 1.0),
#    None], 'winoutput2': [('wm/concept/environment/natural_resources/land',
#     1.0),
#    None,
#    ('wm/process/preparation', 1.0),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   22397,
#   22408): {'amyoutput': [('wm/property/preparedness', 0.9654415845870972),
#    None,
#    None,
#    None], 'text': 'and planting', 'winoutput1': [('wm/process/farming/planting',
#     1.0),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/farming/planting', 1.0),
#    None,
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   22592,
#   22630): {'amyoutput': [('wm/process/access', 1.0),
#    ('wm/property/geographic_resolution/national', 0.9240543246269226),
#    None,
#    None], 'text': 'no major conflicts over resource access', 'winoutput1': [('wm/concept/crisis_or_disaster/conflict',
#     1.0),
#    None,
#    ('wm/process/access', 1.0),
#    None], 'winoutput2': [('wm/concept/crisis_or_disaster/conflict', 1.0),
#    None,
#    ('wm/process/access', 1.0),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   22663,
#   22691): {'amyoutput': [('wm/concept/goods/water', 1.0),
#    ('wm/property/availability', 1.0),
#    None,
#    None], 'text': 'Forage and water availability', 'winoutput1': [('wm/concept/goods/water',
#     1.0),
#    ('wm/property/availability', 1.0),
#    None,
#    None], 'winoutput2': [('wm/concept/goods/water', 1.0),
#    ('wm/property/availability', 1.0),
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   22776,
#   22814): {'amyoutput': [('wm/concept/time/belg', 1.0),
#    None,
#    ('wm/process/damage', 0.8130885362625122),
#    None], 'text': 'mostly normal performance of Belg rains', 'winoutput1': [('wm/concept/time/belg',
#     1.0),
#    None,
#    ('wm/process/stay_or_remain', 0.5172331929206848),
#    None], 'winoutput2': [('wm/concept/time/belg', 1.0),
#    None,
#    ('wm/process/stay_or_remain', 0.5374682545661926),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   22830,
#   22849): {'amyoutput': [('wm/concept/environment/natural_resources/land/pasture',
#     1.0),
#    ('wm/property/availability', 1.0),
#    None,
#    None], 'text': 'pasture availability', 'winoutput1': [('wm/concept/environment/natural_resources/land/pasture',
#     1.0),
#    ('wm/property/availability', 1.0),
#    None,
#    None], 'winoutput2': [('wm/concept/environment/natural_resources/land/pasture',
#     1.0),
#    ('wm/property/availability', 1.0),
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   22853,
#   22870): {'amyoutput': [('wm/concept/goods/water', 1.0),
#    ('wm/property/availability', 1.0),
#    None,
#    None], 'text': 'Water availability', 'winoutput1': [('wm/concept/goods/water',
#     1.0),
#    ('wm/property/availability', 1.0),
#    None,
#    None], 'winoutput2': [('wm/concept/goods/water', 1.0),
#    ('wm/property/availability', 1.0),
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   22893,
#   22934): {'amyoutput': [('wm/process/repair', 0.8039758801460266),
#    ('wm/property/widespread', 1.0096060037612915),
#    None,
#    None], 'text': 'most parts of East and West Hararghe Zones', 'winoutput1': [('wm/process/stay_or_remain',
#     0.5176553726196289),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/stay_or_remain', 0.5128904581069946),
#    None,
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   22951,
#   22963): {'amyoutput': [('wm/concept/entity/locations/lowland_area',
#     1.300977110862732),
#    None,
#    None,
#    None], 'text': 'lowland areas', 'winoutput1': [('wm/concept/entity/locations/lowland_area',
#     0.680424690246582),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/entity/locations/lowland_area',
#     0.7515206933021545),
#    None,
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   23104,
#   23165): {'amyoutput': [('wm/concept/goods/water', 1.0),
#    None,
#    ('wm/process/start', 0.9207333922386169),
#    None], 'text': 'However, in West Hararghe Zone, water trucking recently ceased', 'winoutput1': [('wm/concept/goods/water',
#     1.0),
#    None,
#    ('wm/process/decision', 0.5998024344444275),
#    None], 'winoutput2': [('wm/concept/goods/water', 1.0),
#    None,
#    ('wm/process/remediation', 0.5706174373626709),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   23178,
#   23239): {'amyoutput': [('wm/concept/goods/water', 1.0),
#    None,
#    ('wm/process/consumption', 1.0),
#    None], 'text': 'availability of water both for human and livestock consumption', 'winoutput1': [('wm/concept/goods/water',
#     1.0),
#    None,
#    ('wm/process/consumption', 1.0),
#    None], 'winoutput2': [('wm/concept/goods/water', 1.0),
#    None,
#    ('wm/process/consumption', 1.0),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   23252,
#   23275): {'amyoutput': [('wm/concept/agriculture/livestock', 1.0),
#    ('wm/property/condition', 1.9183697700500488),
#    None,
#    None], 'text': 'conditions for livestock', 'winoutput1': [('wm/concept/agriculture/livestock',
#     1.0),
#    ('wm/property/condition', 0.9387773871421814),
#    None,
#    None], 'winoutput2': [('wm/concept/agriculture/livestock', 1.0),
#    ('wm/property/condition', 0.9387773871421814),
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   23321,
#   23345): {'amyoutput': [('wm/concept/goods/water', 1.0),
#    ('wm/property/availability', 1.0),
#    None,
#    None], 'text': 'normal water availability', 'winoutput1': [('wm/concept/goods/water',
#     1.0),
#    None,
#    ('wm/process/prevention', 0.507210373878479),
#    None], 'winoutput2': [('wm/concept/goods/water', 1.0),
#    None,
#    ('wm/process/hatching', 0.5107250213623047),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   23492,
#   23604): {'amyoutput': [('wm/concept/time/wet_season', 1.0),
#    None,
#    ('wm/process/farming/herding', 1.814504623413086),
#    None], 'text': 'livestock have not been returned to their normal wet season grazing areas as water points are not yet replenished', 'winoutput1': [('wm/concept/time/wet_season',
#     1.0),
#    None,
#    ('wm/process/farming/herding', 0.8608784079551697),
#    None], 'winoutput2': [('wm/concept/time/wet_season', 1.0),
#    None,
#    ('wm/process/farming/herding', 0.8608784079551697),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   23528,
#   23564): {'amyoutput': [('wm/concept/time/wet_season', 1.0),
#    None,
#    ('wm/process/farming/herding', 1.814504623413086),
#    None], 'text': 'their normal wet season grazing areas', 'winoutput1': [('wm/concept/time/wet_season',
#     1.0),
#    None,
#    ('wm/process/farming/herding', 0.8608784079551697),
#    None], 'winoutput2': [('wm/concept/time/wet_season', 1.0),
#    None,
#    ('wm/process/farming/herding', 0.8608784079551697),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   23753,
#   23774): {'amyoutput': [('wm/concept/entity/border', 0.9534215927124023),
#    None,
#    ('wm/process/conflict/resolution', 0.7659049034118652),
#    None], 'text': 'Boundary demarcation p', 'winoutput1': [('wm/concept/entity/border',
#     0.5234540104866028),
#    None,
#    ('wm/process/conflict/disarmament', 0.40017926692962646),
#    None], 'winoutput2': [('wm/concept/entity/border', 0.5526479482650757),
#    None,
#    ('wm/process/conflict/resolution', 0.442144513130188),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   23955,
#   24014): {'amyoutput': [('wm/concept/entity/border', 0.7104198932647705),
#    None,
#    ('wm/process/start', 1.0),
#    None], 'text': 'However, this demarcation has not yet started in these areas', 'winoutput1': [('wm/concept/time/timely',
#     0.6045334935188293),
#    None,
#    ('wm/process/start', 1.0),
#    None], 'winoutput2': [('wm/concept/entity/locations/urban_area',
#     0.6248953342437744),
#    None,
#    ('wm/process/start', 1.0),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   24103,
#   24262): {'amyoutput': [('wm/concept/entity/people/migration/displaced_person',
#     1.0),
#    None,
#    ('wm/process/population/migrate/migrate', 1.101327657699585),
#    None], 'text': 'Internally displaced persons (IDPs) who fled the conflict in four kebeles of Meyu Muluke and six kebeles of Qumbi have not yet returned to their areas or origin', 'winoutput1': [('wm/concept/entity/people/migration/displaced_person',
#     1.0),
#    None,
#    ('wm/process/conflict', 1.0),
#    None], 'winoutput2': [('wm/concept/entity/people/migration/displaced_person',
#     1.0),
#    None,
#    ('wm/process/conflict', 1.0),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   24276,
#   24287): {'amyoutput': [('wm/concept/entity/people/migration/displaced_person',
#     0.9106356501579285),
#    None,
#    None,
#    None], 'text': 'displacement', 'winoutput1': [('wm/concept/entity/people/migration/displaced_person',
#     0.5206096172332764),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/entity/people/migration/displaced_person',
#     0.5973207950592041),
#    None,
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   24290,
#   24362): {'amyoutput': [('wm/concept/time/belg', 1.0),
#    None,
#    ('wm/process/farming/planting', 1.0),
#    None], 'text': 'planting of both Belg and long-cycle Meher crops has not been on schedule', 'winoutput1': [('wm/concept/time/belg',
#     1.0),
#    None,
#    ('wm/process/farming/planting', 1.0),
#    None], 'winoutput2': [('wm/concept/time/belg', 1.0),
#    None,
#    ('wm/process/farming/planting', 1.0),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   24374,
#   24414): {'amyoutput': [('wm/concept/entity/locations/woreda', 1.0),
#    None,
#    ('wm/process/stay_or_remain', 0.8095689415931702),
#    None], 'text': 'near normal planted area in either woreda', 'winoutput1': [('wm/concept/entity/locations/woreda',
#     1.0),
#    None,
#    ('wm/process/farming/planting', 0.8879470825195312),
#    None], 'winoutput2': [('wm/concept/entity/locations/woreda', 1.0),
#    None,
#    ('wm/process/farming/planting', 0.8879470825195312),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   24568,
#   24592): {'amyoutput': [('wm/property/preparedness', 1.0279743671417236),
#    None,
#    None,
#    None], 'text': 'Efforts by the government', 'winoutput1': [('wm/concept/government',
#     1.0),
#    None,
#    ('wm/process/attempt', 0.7237265110015869),
#    None], 'winoutput2': [('wm/concept/government', 1.0),
#    None,
#    ('wm/process/attempt', 0.7903582453727722),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   24656,
#   24692): {'amyoutput': [('wm/concept/time/meher', 1.0),
#    None,
#    ('wm/process/farming/harvesting', 1.9024419784545898),
#    None], 'text': 'above average 2013-2014 Meher harvest', 'winoutput1': [('wm/concept/time/meher',
#     1.0),
#    None,
#    ('wm/process/farming/harvesting', 0.9268314838409424),
#    None], 'winoutput2': [('wm/concept/time/meher', 1.0),
#    None,
#    ('wm/process/farming/harvesting', 0.9268314838409424),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   24779,
#   24826): {'amyoutput': [('wm/process/population/migrate/emigrate',
#     0.5107707381248474),
#    ('wm/property/diversity', 0.9869760274887085),
#    None,
#    None], 'text': 'marginal agricultural areas in Tigray and Amhara', 'winoutput1': [('wm/concept/goods/agricultural',
#     1.0),
#    None,
#    ('wm/process/development', 0.5254734754562378),
#    None], 'winoutput2': [('wm/concept/goods/agricultural', 1.0),
#    None,
#    ('wm/process/transmission', 0.5137871503829956),
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   25001,
#   25020): {'amyoutput': [('wm/property/availability', 1.0048799514770508),
#    None,
#    None,
#    None], 'text': 'mostly normal supply', 'winoutput1': [('wm/process/consumption',
#     0.5828211903572083),
#    None,
#    None,
#    None], 'winoutput2': [('wm/process/consumption', 0.5806748270988464),
#    None,
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   25023,
#   25050): {'amyoutput': [('wm/concept/goods/food', 1.419047236442566),
#    None,
#    ('wm/process/combining', 0.6857187747955322),
#    ('wm/property/price_or_cost',
#     1.0)], 'text': 'prices of major staple foods', 'winoutput1': [('wm/concept/goods/food',
#     1.0),
#    None,
#    ('wm/process/research', 0.5052633285522461),
#    None], 'winoutput2': [('wm/concept/goods/food', 1.0),
#    ('wm/property/price_or_cost', 1.0),
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   25072,
#   25083): {'amyoutput': [('wm/property/diversity', 1.008248209953308),
#    None,
#    None,
#    None], 'text': 'most markets', 'winoutput1': [('wm/concept/economy/commerce',
#     0.732629656791687),
#    None,
#    None,
#    None], 'winoutput2': [('wm/concept/economy/commerce', 0.8099005222320557),
#    None,
#    None,
#    None]},
#  ('0a94f8c62f1291636f8a65840d914099',
#   25164,
#   25176): {'amyoutput': [('wm/process/consumption', 0.848368227481842),
#    ('wm/property/price_or_cost', 1.007371425628662),
#    None,
#    None], 'text': 'higher volume', 'winoutput1': [('wm/concept/environment/climate_change/higher_temperatures',
#     0.5487390160560608),
#    None,
#    ('wm/process/consumption', 0.4267462491989136),
#    None], 'winoutput2': [('wm/concept/environment/climate_change/higher_temperatures',
#     0.5411682724952698),
#    None,
#    ('wm/process/consumption', 0.464838445186615),
#    None]},
#  ...}

# %%
rows = [['text'] + parts + ['key']]
for key, entry in groundings_by_indexed_event.items():
    rows.append([entry['text']] + [str(entry.get(part)) for part in parts] + [key])

# %%
rows[0]
# Out:
# ['text', 'amyoutput', 'winoutput1', 'winoutput2', 'key']

# %%
with open('grounding_comparison.csv', 'w') as fh:
    wr = csv.writer(fh)
    wr.writerows(rows)

# %%
rows[1]
# Out:
# ['climate news',
#  "[('wm/concept/environment/climate', 1.0), None, ('wm/process/communication/informing', 0.876518726348877), None]",
#  "[('wm/concept/environment/climate', 1.0), None, ('wm/process/communication/informing', 0.44785910844802856), None]",
#  "[('wm/concept/environment/climate', 1.0), None, ('wm/process/publication', 0.42294541001319885), None]"]

# %%
from indra_world.service.controller import preparation_pipeline

# %%
assembled_stmts = {part: preparation_pipeline.run(stmts[part]) for part in parts}
# Out:
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Running the pipeline
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling filter_by_type
# INFO: [2022-03-09 23:13:16] indra.tools.assemble_corpus - Filtering 4668 statements for type Influence...
# INFO: [2022-03-09 23:13:16] indra.tools.assemble_corpus - 546 statements after filter...
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling validate_grounding_format
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling remove_namespaces
# INFO: [2022-03-09 23:13:16] indra_world.assembly.operations - Removing unnecessary namespaces
# INFO: [2022-03-09 23:13:16] indra_world.assembly.operations - Finished removing unnecessary namespaces
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling compositional_grounding_filter
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling validate_grounding_format
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling filter_out_long_words
# INFO: [2022-03-09 23:13:16] indra_world.assembly.operations - Filtering to concepts with max 10 words on 502 statements.
# INFO: [2022-03-09 23:13:16] indra_world.assembly.operations - 383 statements after filter.
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling filter_context_date
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling datetime
# INFO: [2022-03-09 23:13:16] indra_world.assembly.operations - Filtering dates on 383 statements
# INFO: [2022-03-09 23:13:16] indra_world.assembly.operations - 383 statements after date filter
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling set_positive_polarities
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling sort_compositional_groundings
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Running the pipeline
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling filter_by_type
# INFO: [2022-03-09 23:13:16] indra.tools.assemble_corpus - Filtering 5469 statements for type Influence...
# INFO: [2022-03-09 23:13:16] indra.tools.assemble_corpus - 632 statements after filter...
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling validate_grounding_format
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling remove_namespaces
# INFO: [2022-03-09 23:13:16] indra_world.assembly.operations - Removing unnecessary namespaces
# INFO: [2022-03-09 23:13:16] indra_world.assembly.operations - Finished removing unnecessary namespaces
# INFO: [2022-03-09 23:13:16] indra.pipeline.pipeline - Calling compositional_grounding_filter
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling validate_grounding_format
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling filter_out_long_words
# INFO: [2022-03-09 23:13:17] indra_world.assembly.operations - Filtering to concepts with max 10 words on 351 statements.
# INFO: [2022-03-09 23:13:17] indra_world.assembly.operations - 265 statements after filter.
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling filter_context_date
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling datetime
# INFO: [2022-03-09 23:13:17] indra_world.assembly.operations - Filtering dates on 265 statements
# INFO: [2022-03-09 23:13:17] indra_world.assembly.operations - 265 statements after date filter
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling set_positive_polarities
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling sort_compositional_groundings
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Running the pipeline
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling filter_by_type
# INFO: [2022-03-09 23:13:17] indra.tools.assemble_corpus - Filtering 5469 statements for type Influence...
# INFO: [2022-03-09 23:13:17] indra.tools.assemble_corpus - 632 statements after filter...
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling validate_grounding_format
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling remove_namespaces
# INFO: [2022-03-09 23:13:17] indra_world.assembly.operations - Removing unnecessary namespaces
# INFO: [2022-03-09 23:13:17] indra_world.assembly.operations - Finished removing unnecessary namespaces
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling compositional_grounding_filter
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling validate_grounding_format
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling filter_out_long_words
# INFO: [2022-03-09 23:13:17] indra_world.assembly.operations - Filtering to concepts with max 10 words on 365 statements.
# INFO: [2022-03-09 23:13:17] indra_world.assembly.operations - 281 statements after filter.
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling filter_context_date
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling datetime
# INFO: [2022-03-09 23:13:17] indra_world.assembly.operations - Filtering dates on 281 statements
# INFO: [2022-03-09 23:13:17] indra_world.assembly.operations - 281 statements after date filter
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling set_positive_polarities
# INFO: [2022-03-09 23:13:17] indra.pipeline.pipeline - Calling sort_compositional_groundings

# %%
for part in parts:
    print(part, len(assembled_stmts[part]))
# Out:
# amyoutput 383
# winoutput1 265
# winoutput2 281

# %%
preparation_pipeline.steps
# Out:
# [{'function': 'filter_by_type', 'kwargs': {'stmt_type': 'Influence'}},
#  {'function': 'validate_grounding_format'},
#  {'function': 'remove_namespaces', 'args': [['WHO', 'MITRE12', 'UN']]},
#  {'function': 'compositional_grounding_filter',
#   'kwargs': {'score_threshold': 0.6,
#    'groundings_to_exclude': ['wm',
#     'wm/concept',
#     'wm/entity',
#     'wm/time',
#     'wm/process',
#     'wm/property'],
#    'remove_self_loops': True}},
#  {'function': 'validate_grounding_format'},
#  {'function': 'filter_out_long_words', 'args': [10]},
#  {'function': 'filter_context_date',
#   'kwargs': {'from_date': {'function': 'datetime', 'args': [1900, 1, 1]}}},
#  {'function': 'set_positive_polarities'},
#  {'function': 'sort_compositional_groundings'}]
